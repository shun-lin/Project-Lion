# %%
# !pip install sentencepiece
# !pip install segtok
# Out:
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/00/95/7f357995d5eb1131aa2092096dca14a6fc1b1d2860bd99c22a612e1d1019/sentencepiece-0.1.82-cp36-cp36m-manylinux1_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 8.9MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.82
# Collecting segtok
#   Downloading https://files.pythonhosted.org/packages/1d/59/6ed78856ab99d2da04084b59e7da797972baa0efecb71546b16d48e49d9b/segtok-1.5.7.tar.gz
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from segtok) (2018.1.10)
# Building wheels for collected packages: segtok
#   Building wheel for segtok (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/15/ee/a8/6112173f1386d33eebedb3f73429cfa41a4c3084556bcee254
# Successfully built segtok
# Installing collected packages: segtok
# Successfully installed segtok-1.5.7

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import sentencepiece as spm
import tensorflow as tf
import numpy as np
import os, sys
import json
import matplotlib.pyplot as plt
import pandas as pd
import string

sys.path.insert(0, "/content/gdrive/My Drive/Project-Lion/") # This enables us to import Python libraries in the folder.

from transformer import Transformer
import capita

root_folder = "/content/gdrive/My Drive/Project-Lion/"

# %%
# Load the word piece model that will be used to tokenize the texts into
# word pieces with a vocabulary size of 10000

sp = spm.SentencePieceProcessor()
sp.Load(root_folder+"dataset/wp_vocab10000.model")

vocab = [line.split('\t')[0] for line in open(root_folder+"dataset/wp_vocab10000.vocab", "r")]
pad_index = vocab.index('#')
end_index = vocab.index('`')

# %%
df = pd.read_csv(root_folder + 'data/kaggle/shortjokes.csv')
df = df.loc[df["Joke"] != ""]

# %%
def clean_data(lst, in_place=True, keep_punc=""):
    if in_place:
        new_lst = lst
    else:
        new_lst = lst.copy()
        
    for i in range(len(new_lst)):
        joke = lst[i]
        joke = joke.replace("\r", " ").replace("\n", " ").replace("/", " or ")
        joke = joke.translate(str.maketrans("", "", string.punctuation.replace(keep_punc, ""))) # Remove punctuation
        joke = joke.lower() # Lowercase
        joke = ''.join(char for char in joke if not char.isdigit()) # Remove numbers
        joke = joke.strip() # Remove leading and ending whitespace
        new_lst[i] = joke
    return new_lst

# %%
data = clean_data(df["Joke"].tolist(), keep_punc="?")

# %%
qa_all = [[s.strip() for s in list(filter(None, joke.split("?")))] for joke in data if len(list(filter(None, joke.split("?")))) == 2]
print("Size of entire dataset:", len(qa_all))
print(qa_all[0])
# Out:
# Size of entire dataset: 93782
# ['why cant barbie get pregnant', 'because ken comes in a different box heyooooooo']

# %%
min_qlen, max_qlen = 3, 15
min_alen, max_alen = 3, 15
qa = [(q, a) for q, a in qa_all if len(q.split()) >= min_qlen and len(q.split()) <= max_qlen and len(a.split()) >= min_alen and len(a.split()) <= max_alen]
print("Size of dataset:", len(qa))
print(qa[0])
# Out:
# Size of dataset: 59999
# ('why cant barbie get pregnant', 'because ken comes in a different box heyooooooo')

# %%
def pad_sequence(numerized, pad_index, to_length, end_index=None):
    pad = numerized[:to_length]
    if end_index != None:
      padded = pad + [end_index] + [pad_index] * (to_length - len(pad))
    else:
      padded = pad + [pad_index] * (to_length - len(pad))
    mask = [w != pad_index for w in padded]
    return padded, mask

# %%
dataset = []
for q, a in qa:
  d = {}
  # Tokenize, numerize
  d['input'] = sp.EncodeAsIds(capita.preprocess_capitalization(q))
  d['output'] = sp.EncodeAsIds(capita.preprocess_capitalization(a))

  # Padding    
  d['input'], d['input_mask'] =  pad_sequence(d['input'],  pad_index, max_qlen)
  d['output'], d['output_mask'] = pad_sequence(d['output'], pad_index, max_alen, end_index=end_index)
  dataset.append(d)
  
input_len = max_qlen
output_len = max_alen + 1

# %%
dataset_size = len(dataset)
training_size = (dataset_size * 9) // 10

d_train = dataset[:training_size]
d_valid = dataset[training_size:]

len(d_train), len(d_valid)
# Out:
# (53999, 6000)

# %%
def build_batch(dataset, batch_size):
    indices = list(np.random.randint(0, len(dataset), size=batch_size))
    
    batch = [dataset[i] for i in indices]
    batch_input = np.array([a['input'] for a in batch])
    batch_input_mask = np.array([a['input_mask'] for a in batch])
    batch_output = np.array([a['output'] for a in batch])
    batch_output_mask = np.array([a['output_mask'] for a in batch])
    
    return batch_input, batch_input_mask, batch_output, batch_output_mask

# %%
# We are giving you the trainer, as it is similar to the one
# you created in the Language Modeling assignment.

class TransformerTrainer():

    def __init__(self, vocab_size, d_model, input_length, output_length, n_layers, d_filter, learning_rate=1e-3):

        self.source_sequence = tf.placeholder(tf.int32,shape=(None,input_length), name="source_sequence")
        self.target_sequence = tf.placeholder(tf.int32, shape=(None,output_length),name="target_sequence")
        self.encoder_mask = tf.placeholder(tf.bool,shape=(None,input_length),name="encoder_mask")
        self.decoder_mask = tf.placeholder(tf.bool, shape=(None,output_length),name="decoder_mask")

        self.model = Transformer(vocab_size=vocab_size, d_model=d_model, n_layers=n_layers, d_filter=d_filter)

        self.decoded_logits = self.model(self.source_sequence, self.target_sequence, encoder_mask=self.encoder_mask, decoder_mask=self.decoder_mask)
        self.global_step = tf.Variable(0, trainable=False)
        learning_rate = tf.train.exponential_decay(learning_rate, self.global_step, 100000, 0.96)
        
        # Summarization loss
        self.loss = tf.losses.sparse_softmax_cross_entropy(self.target_sequence, self.decoded_logits, tf.cast(self.decoder_mask, tf.float32))
        self.optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate, beta1=0.9, beta2=0.98, epsilon=1e-9)
        self.train_op = self.optimizer.minimize(self.loss, global_step=self.global_step)
        self.saver = tf.train.Saver()

# %%
def predict(model, model_file, questions=[], size=10, start_idx=None):
  
  sample = questions == []
  if sample:
    if start_idx == None:
      start_idx = np.random.randint(training_size, len(qa) - size)
    questions = [q for q, a in qa[start_idx:start_idx + size]]
    answers = [a for q, a in qa[start_idx:start_idx + size]]

  with tf.Session() as sess:

    model.saver.restore(sess, model_file)
    
    if sample:
      print("\nJokes starting from index:", start_idx)

    for i in range(len(questions)):
      question = questions[i]

      # Process the capitalization with the preprocess_capitalization of the capita package.
      question = capita.preprocess_capitalization(question)

      # Numerize the tokens of the processed text using the loaded sentencepiece model.
      numerized = sp.EncodeAsIds(question)
      # Pad the sequence and keep the mask of the input
      padded, mask = pad_sequence(numerized, pad_index, input_len)

      # Making the news article into a batch of size one, to be fed to the neural network.
      encoder_input = np.array([padded])
      encoder_mask = np.array([mask])

      decoded_so_far = [0]

      for j in range(output_len):
        padded_decoder_input, decoder_mask = pad_sequence(decoded_so_far, pad_index, output_len)
        padded_decoder_input = [padded_decoder_input]
        decoder_mask = [decoder_mask]
        #print("========================")
        #print(padded_decoder_input)
        # Use the model to find the distrbution over the vocabulary for the next word
        logits = sess.run(model.decoded_logits, feed_dict={model.source_sequence: encoder_input, model.encoder_mask: encoder_mask, model.target_sequence: padded_decoder_input, model.decoder_mask: decoder_mask})

        chosen_words = np.argmax(logits, axis=2) # Take the argmax, getting the most likely next word
        decoded_so_far.append(int(chosen_words[0, j])) # We add it to the summary so far

      print("\n=================================================\n")
      print("Question:", question)
      if sample:
        answer = answers[i]
        print("Answer:", answer)
      print("Predicted answer:", "".join([vocab[i] for i in decoded_so_far]).replace("▁", " "))

# %% [markdown]
# # Initialize Model

# %%
# Dataset related parameters
vocab_size = len(vocab)
input_len = input_len # Length of the article
output_len = output_len # Length of the summaries

# Model related parameters, feel free to modify these.
n_layers = 6
d_model  = 256
d_filter = 416

tf.reset_default_graph()
model = TransformerTrainer(vocab_size, d_model, input_len, output_len, n_layers, d_filter, learning_rate=1e-3)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/losses/losses_impl.py:209: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %% [markdown]
# # Initial Training

# %%
model_file = root_folder + "models/transformer_model2"

batch_size = 50
epochs = 10

iter_per_epoch = len(d_train) // batch_size
total_iterations = iter_per_epoch * epochs
print_per_iter = 10
eval_per_iter = 50
save_per_iter = 100

print("Total iterations:", total_iterations)

train_losses = []
val_losses = []
iterations = []

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    iteration = 1
    for epoch in range(1, epochs + 1):
        print("Epoch:", epoch)
        for _ in range(iter_per_epoch):
            batch_input, batch_input_mask, batch_output, batch_output_mask = build_batch(d_train, batch_size)
            feed = {model.source_sequence: batch_input, model.target_sequence: batch_output,
                              model.encoder_mask: batch_input_mask, model.decoder_mask: batch_output_mask}

            train_loss, _, step = sess.run([model.loss, model.train_op, model.global_step], feed_dict=feed)

            if iteration % print_per_iter == 0:
                print("Iteration {0} / {1}: Training loss - {2}".format(iteration, total_iterations, train_loss))

            if iteration % eval_per_iter == 0:
                batch_input, batch_input_mask, batch_output, batch_output_mask = build_batch(d_valid, batch_size)
                feed = {model.source_sequence: batch_input, model.target_sequence: batch_output,
                              model.encoder_mask: batch_input_mask, model.decoder_mask: batch_output_mask}
                eval_loss = sess.run(model.loss, feed_dict=feed)
                print("Evaluation loss:", eval_loss)
                val_losses.append(eval_loss)
                train_losses.append(train_loss)
                iterations.append(iteration)
                
            if iteration % save_per_iter == 0:
                model.saver.save(sess, model_file)
                np.save(root_folder + "models/transformer_model2_train_losses", np.array(train_losses))
                np.save(root_folder + "models/transformer_model2_val_losses", np.array(val_losses))
                np.save(root_folder + "models/transformer_model2_iterations", np.array(iterations))
                
            iteration += 1
# Out:
# Total iterations: 10790
# Epoch: 1
# Iteration 10 / 10790: Training loss - 10.201056480407715
# Iteration 20 / 10790: Training loss - 8.159419059753418
# Iteration 30 / 10790: Training loss - 7.761689186096191
# Iteration 40 / 10790: Training loss - 7.868720054626465
# Iteration 50 / 10790: Training loss - 7.974294662475586
# Evaluation loss: 7.8620114
# Iteration 60 / 10790: Training loss - 7.8777666091918945
# Iteration 70 / 10790: Training loss - 7.453268527984619
# Iteration 80 / 10790: Training loss - 8.822704315185547
# Iteration 90 / 10790: Training loss - 7.746514320373535
# Iteration 100 / 10790: Training loss - 7.38507604598999
# Evaluation loss: 7.7832465
# Iteration 110 / 10790: Training loss - 7.328062534332275
# Iteration 120 / 10790: Training loss - 7.38136625289917
# Iteration 130 / 10790: Training loss - 7.394535064697266
# Iteration 140 / 10790: Training loss - 7.655372619628906
# Iteration 150 / 10790: Training loss - 7.347259998321533
# Evaluation loss: 7.484049
# Iteration 160 / 10790: Training loss - 7.290980339050293
# Iteration 170 / 10790: Training loss - 7.51348876953125
# Iteration 180 / 10790: Training loss - 7.10045862197876
# Iteration 190 / 10790: Training loss - 7.110827922821045
# Iteration 200 / 10790: Training loss - 7.170615196228027
# Evaluation loss: 7.191971
# Iteration 210 / 10790: Training loss - 7.237331867218018
# Iteration 220 / 10790: Training loss - 7.089721202850342
# Iteration 230 / 10790: Training loss - 6.982153415679932
# Iteration 240 / 10790: Training loss - 6.955130100250244
# Iteration 250 / 10790: Training loss - 7.0890045166015625
# Evaluation loss: 6.509734
# Iteration 260 / 10790: Training loss - 6.733972072601318
# Iteration 270 / 10790: Training loss - 6.726792812347412
# Iteration 280 / 10790: Training loss - 6.761317729949951
# Iteration 290 / 10790: Training loss - 6.804698944091797
# Iteration 300 / 10790: Training loss - 6.706643104553223
# Evaluation loss: 6.7615795
# Iteration 310 / 10790: Training loss - 6.652942180633545
# Iteration 320 / 10790: Training loss - 6.515623569488525
# Iteration 330 / 10790: Training loss - 6.770211696624756
# Iteration 340 / 10790: Training loss - 6.585276126861572
# Iteration 350 / 10790: Training loss - 6.578847885131836
# Evaluation loss: 6.3690767
# Iteration 360 / 10790: Training loss - 6.181902885437012
# Iteration 370 / 10790: Training loss - 6.435564041137695
# Iteration 380 / 10790: Training loss - 6.235053062438965
# Iteration 390 / 10790: Training loss - 6.264939785003662
# Iteration 400 / 10790: Training loss - 6.370640754699707
# Evaluation loss: 6.3400717
# Iteration 410 / 10790: Training loss - 6.246233940124512
# Iteration 420 / 10790: Training loss - 6.195910930633545
# Iteration 430 / 10790: Training loss - 5.989954948425293
# Iteration 440 / 10790: Training loss - 6.267131805419922
# Iteration 450 / 10790: Training loss - 6.46463680267334
# Evaluation loss: 6.296517
# Iteration 460 / 10790: Training loss - 6.357635021209717
# Iteration 470 / 10790: Training loss - 6.301602840423584
# Iteration 480 / 10790: Training loss - 6.076025485992432
# Iteration 490 / 10790: Training loss - 6.272733211517334
# Iteration 500 / 10790: Training loss - 6.312171459197998
# Evaluation loss: 6.159347
# Iteration 510 / 10790: Training loss - 6.203806400299072
# Iteration 520 / 10790: Training loss - 6.300821781158447
# Iteration 530 / 10790: Training loss - 5.957315444946289
# Iteration 540 / 10790: Training loss - 6.1577887535095215
# Iteration 550 / 10790: Training loss - 5.865814208984375
# Evaluation loss: 6.0789766
# Iteration 560 / 10790: Training loss - 6.1231818199157715
# Iteration 570 / 10790: Training loss - 6.0833353996276855
# Iteration 580 / 10790: Training loss - 5.95014762878418
# Iteration 590 / 10790: Training loss - 6.315328121185303
# Iteration 600 / 10790: Training loss - 6.070740222930908
# Evaluation loss: 5.7867146
# Iteration 610 / 10790: Training loss - 5.943945407867432
# Iteration 620 / 10790: Training loss - 5.994748592376709
# Iteration 630 / 10790: Training loss - 6.298893451690674
# Iteration 640 / 10790: Training loss - 5.806772232055664
# Iteration 650 / 10790: Training loss - 5.936600685119629
# Evaluation loss: 6.223416
# Iteration 660 / 10790: Training loss - 5.806603908538818
# Iteration 670 / 10790: Training loss - 5.749781131744385
# Iteration 680 / 10790: Training loss - 6.042175769805908
# Iteration 690 / 10790: Training loss - 6.130654811859131
# Iteration 700 / 10790: Training loss - 5.963129997253418
# Evaluation loss: 6.0817323
# Iteration 710 / 10790: Training loss - 6.313230991363525
# Iteration 720 / 10790: Training loss - 5.7858099937438965
# Iteration 730 / 10790: Training loss - 5.720085144042969
# Iteration 740 / 10790: Training loss - 5.477147579193115
# Iteration 750 / 10790: Training loss - 5.870491981506348
# Evaluation loss: 5.9711385
# Iteration 760 / 10790: Training loss - 5.459465503692627
# Iteration 770 / 10790: Training loss - 5.728248119354248
# Iteration 780 / 10790: Training loss - 5.864384174346924
# Iteration 790 / 10790: Training loss - 5.800148010253906
# Iteration 800 / 10790: Training loss - 5.265416145324707
# Evaluation loss: 5.6106925
# Iteration 810 / 10790: Training loss - 5.800648212432861
# Iteration 820 / 10790: Training loss - 5.736668109893799
# Iteration 830 / 10790: Training loss - 5.715324878692627
# Iteration 840 / 10790: Training loss - 5.618685722351074
# Iteration 850 / 10790: Training loss - 5.2747697830200195
# Evaluation loss: 6.1299543
# Iteration 860 / 10790: Training loss - 5.9934492111206055
# Iteration 870 / 10790: Training loss - 5.808084011077881
# Iteration 880 / 10790: Training loss - 5.502044677734375
# Iteration 890 / 10790: Training loss - 5.481229782104492
# Iteration 900 / 10790: Training loss - 5.326315879821777
# Evaluation loss: 5.629882
# Iteration 910 / 10790: Training loss - 5.47581148147583
# Iteration 920 / 10790: Training loss - 5.743183612823486
# Iteration 930 / 10790: Training loss - 5.417424201965332
# Iteration 940 / 10790: Training loss - 5.631575107574463
# Iteration 950 / 10790: Training loss - 5.970341682434082
# Evaluation loss: 5.570082
# Iteration 960 / 10790: Training loss - 5.536696434020996
# Iteration 970 / 10790: Training loss - 5.404043197631836
# Iteration 980 / 10790: Training loss - 5.670675754547119
# Iteration 990 / 10790: Training loss - 5.8942108154296875
# Iteration 1000 / 10790: Training loss - 5.240328788757324
# Evaluation loss: 5.8838587
# Iteration 1010 / 10790: Training loss - 5.614727020263672
# Iteration 1020 / 10790: Training loss - 5.767469882965088
# Iteration 1030 / 10790: Training loss - 5.576898574829102
# Iteration 1040 / 10790: Training loss - 5.82534122467041
# Iteration 1050 / 10790: Training loss - 6.022541046142578
# Evaluation loss: 5.79838
# Iteration 1060 / 10790: Training loss - 5.5389604568481445
# Iteration 1070 / 10790: Training loss - 5.710761070251465
# Epoch: 2
# Iteration 1080 / 10790: Training loss - 5.828722953796387
# Iteration 1090 / 10790: Training loss - 5.255636692047119
# Iteration 1100 / 10790: Training loss - 5.263194561004639
# Evaluation loss: 5.6629453
# Iteration 1110 / 10790: Training loss - 5.538120269775391
# Iteration 1120 / 10790: Training loss - 5.92354679107666
# Iteration 1130 / 10790: Training loss - 5.679348468780518
# Iteration 1140 / 10790: Training loss - 5.137669086456299
# Iteration 1150 / 10790: Training loss - 5.363046169281006
# Evaluation loss: 5.541581
# Iteration 1160 / 10790: Training loss - 5.674034595489502
# Iteration 1170 / 10790: Training loss - 5.1927385330200195
# Iteration 1180 / 10790: Training loss - 5.427685737609863
# Iteration 1190 / 10790: Training loss - 5.191128730773926
# Iteration 1200 / 10790: Training loss - 5.613992214202881
# Evaluation loss: 5.239018
# Iteration 1210 / 10790: Training loss - 5.410489082336426
# Iteration 1220 / 10790: Training loss - 5.427892208099365
# Iteration 1230 / 10790: Training loss - 5.691001892089844
# Iteration 1240 / 10790: Training loss - 5.208979606628418
# Iteration 1250 / 10790: Training loss - 5.407425403594971
# Evaluation loss: 5.4272885
# Iteration 1260 / 10790: Training loss - 5.269108772277832
# Iteration 1270 / 10790: Training loss - 5.838553428649902
# Iteration 1280 / 10790: Training loss - 5.044012546539307
# Iteration 1290 / 10790: Training loss - 5.309084892272949
# Iteration 1300 / 10790: Training loss - 5.0970845222473145
# Evaluation loss: 5.54282
# Iteration 1310 / 10790: Training loss - 5.714747905731201
# Iteration 1320 / 10790: Training loss - 5.379243850708008
# Iteration 1330 / 10790: Training loss - 5.121521949768066
# Iteration 1340 / 10790: Training loss - 5.481948375701904
# Iteration 1350 / 10790: Training loss - 5.057170867919922
# Evaluation loss: 5.779652
# Iteration 1360 / 10790: Training loss - 5.25863790512085
# Iteration 1370 / 10790: Training loss - 5.031961917877197
# Iteration 1380 / 10790: Training loss - 5.342116832733154
# Iteration 1390 / 10790: Training loss - 5.194947719573975
# Iteration 1400 / 10790: Training loss - 5.243403911590576
# Evaluation loss: 5.2308946
# Iteration 1410 / 10790: Training loss - 5.488786697387695
# Iteration 1420 / 10790: Training loss - 5.001283168792725
# Iteration 1430 / 10790: Training loss - 5.035250663757324
# Iteration 1440 / 10790: Training loss - 5.124159336090088
# Iteration 1450 / 10790: Training loss - 5.334883213043213
# Evaluation loss: 5.3046618
# Iteration 1460 / 10790: Training loss - 4.828250885009766
# Iteration 1470 / 10790: Training loss - 5.210152626037598
# Iteration 1480 / 10790: Training loss - 5.686388969421387
# Iteration 1490 / 10790: Training loss - 5.109467506408691
# Iteration 1500 / 10790: Training loss - 5.449527263641357
# Evaluation loss: 5.3560963
# Iteration 1510 / 10790: Training loss - 5.018579959869385
# Iteration 1520 / 10790: Training loss - 5.41035795211792
# Iteration 1530 / 10790: Training loss - 5.5178375244140625
# Iteration 1540 / 10790: Training loss - 5.459415435791016
# Iteration 1550 / 10790: Training loss - 5.217095851898193
# Evaluation loss: 5.2439766
# Iteration 1560 / 10790: Training loss - 5.410091876983643
# Iteration 1570 / 10790: Training loss - 5.299500465393066
# Iteration 1580 / 10790: Training loss - 5.221475124359131
# Iteration 1590 / 10790: Training loss - 5.166825294494629
# Iteration 1600 / 10790: Training loss - 5.405354976654053
# Evaluation loss: 5.6123433
# Iteration 1610 / 10790: Training loss - 5.216938018798828
# Iteration 1620 / 10790: Training loss - 4.871664524078369
# Iteration 1630 / 10790: Training loss - 4.736172676086426
# Iteration 1640 / 10790: Training loss - 4.854567050933838
# Iteration 1650 / 10790: Training loss - 4.863404273986816
# Evaluation loss: 5.4182854
# Iteration 1660 / 10790: Training loss - 5.223983287811279
# Iteration 1670 / 10790: Training loss - 5.016905784606934
# Iteration 1680 / 10790: Training loss - 5.355251312255859
# Iteration 1690 / 10790: Training loss - 4.820045471191406
# Iteration 1700 / 10790: Training loss - 4.7285332679748535
# Evaluation loss: 5.745928
# Iteration 1710 / 10790: Training loss - 5.641755104064941
# Iteration 1720 / 10790: Training loss - 4.923322677612305
# Iteration 1730 / 10790: Training loss - 5.257434368133545
# Iteration 1740 / 10790: Training loss - 5.329186916351318
# Iteration 1750 / 10790: Training loss - 4.970645904541016
# Evaluation loss: 5.435362
# Iteration 1760 / 10790: Training loss - 5.00205135345459
# Iteration 1770 / 10790: Training loss - 5.2580718994140625
# Iteration 1780 / 10790: Training loss - 5.2370100021362305
# Iteration 1790 / 10790: Training loss - 5.185967445373535
# Iteration 1800 / 10790: Training loss - 5.344779014587402
# Evaluation loss: 4.786185
# Iteration 1810 / 10790: Training loss - 5.441619873046875
# Iteration 1820 / 10790: Training loss - 4.83780574798584
# Iteration 1830 / 10790: Training loss - 5.0226898193359375
# Iteration 1840 / 10790: Training loss - 5.06965970993042
# Iteration 1850 / 10790: Training loss - 4.797741413116455
# Evaluation loss: 5.223859
# Iteration 1860 / 10790: Training loss - 5.332963466644287
# Iteration 1870 / 10790: Training loss - 4.755003929138184
# Iteration 1880 / 10790: Training loss - 5.4521708488464355
# Iteration 1890 / 10790: Training loss - 4.934290409088135
# Iteration 1900 / 10790: Training loss - 4.837020397186279
# Evaluation loss: 5.167227
# Iteration 1910 / 10790: Training loss - 5.3347344398498535
# Iteration 1920 / 10790: Training loss - 4.995429515838623
# Iteration 1930 / 10790: Training loss - 5.173878192901611
# Iteration 1940 / 10790: Training loss - 5.304686546325684
# Iteration 1950 / 10790: Training loss - 5.540859699249268
# Evaluation loss: 5.292807
# Iteration 1960 / 10790: Training loss - 4.680150032043457
# Iteration 1970 / 10790: Training loss - 5.408623695373535
# Iteration 1980 / 10790: Training loss - 5.273601055145264
# Iteration 1990 / 10790: Training loss - 5.001455307006836
# Iteration 2000 / 10790: Training loss - 5.26632833480835
# Evaluation loss: 4.8406096
# Iteration 2010 / 10790: Training loss - 5.152164936065674
# Iteration 2020 / 10790: Training loss - 4.8999247550964355
# Iteration 2030 / 10790: Training loss - 4.660557270050049
# Iteration 2040 / 10790: Training loss - 5.207223892211914
# Iteration 2050 / 10790: Training loss - 5.19750452041626
# Evaluation loss: 5.3160815
# Iteration 2060 / 10790: Training loss - 5.097818374633789
# Iteration 2070 / 10790: Training loss - 4.73748254776001
# Iteration 2080 / 10790: Training loss - 5.526679515838623
# Iteration 2090 / 10790: Training loss - 5.0013227462768555
# Iteration 2100 / 10790: Training loss - 5.179478645324707
# Evaluation loss: 4.642467
# Iteration 2110 / 10790: Training loss - 5.634957313537598
# Iteration 2120 / 10790: Training loss - 5.5568132400512695
# Iteration 2130 / 10790: Training loss - 5.348660945892334
# Iteration 2140 / 10790: Training loss - 4.80639123916626
# Iteration 2150 / 10790: Training loss - 4.501469135284424
# Evaluation loss: 5.1943464
# Epoch: 3
# Iteration 2160 / 10790: Training loss - 4.827939033508301
# Iteration 2170 / 10790: Training loss - 4.830252170562744
# Iteration 2180 / 10790: Training loss - 4.89763069152832
# Iteration 2190 / 10790: Training loss - 4.848352909088135
# Iteration 2200 / 10790: Training loss - 4.877162456512451
# Evaluation loss: 5.301186
# Iteration 2210 / 10790: Training loss - 4.549158096313477
# Iteration 2220 / 10790: Training loss - 5.142462253570557
# Iteration 2230 / 10790: Training loss - 4.983976364135742
# Iteration 2240 / 10790: Training loss - 5.058628559112549
# Iteration 2250 / 10790: Training loss - 5.169334411621094
# Evaluation loss: 4.864648
# Iteration 2260 / 10790: Training loss - 5.194809913635254
# Iteration 2270 / 10790: Training loss - 4.363142967224121
# Iteration 2280 / 10790: Training loss - 5.02463960647583
# Iteration 2290 / 10790: Training loss - 4.811796188354492
# Iteration 2300 / 10790: Training loss - 5.12839412689209
# Evaluation loss: 4.5752053
# Iteration 2310 / 10790: Training loss - 4.754110336303711
# Iteration 2320 / 10790: Training loss - 4.699828147888184
# Iteration 2330 / 10790: Training loss - 5.371586322784424
# Iteration 2340 / 10790: Training loss - 4.36959981918335
# Iteration 2350 / 10790: Training loss - 4.332618713378906
# Evaluation loss: 5.272665
# Iteration 2360 / 10790: Training loss - 5.021761417388916
# Iteration 2370 / 10790: Training loss - 4.870813846588135
# Iteration 2380 / 10790: Training loss - 4.9120635986328125
# Iteration 2390 / 10790: Training loss - 4.768440246582031
# Iteration 2400 / 10790: Training loss - 5.057011127471924
# Evaluation loss: 5.3407836
# Iteration 2410 / 10790: Training loss - 4.7824530601501465
# Iteration 2420 / 10790: Training loss - 5.070443630218506
# Iteration 2430 / 10790: Training loss - 4.8119916915893555
# Iteration 2440 / 10790: Training loss - 5.267208576202393
# Iteration 2450 / 10790: Training loss - 5.00490665435791
# Evaluation loss: 4.788143
# Iteration 2460 / 10790: Training loss - 4.442957401275635
# Iteration 2470 / 10790: Training loss - 4.756464004516602
# Iteration 2480 / 10790: Training loss - 4.282159805297852
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-4260e9b1ab7e> in <module>()
#      26                               model.encoder_mask: batch_input_mask, model.decoder_mask: batch_output_mask}
#      27
# ---> 28             train_loss, _, step = sess.run([model.loss, model.train_op, model.global_step], feed_dict=feed)
#      29
#      30             if iteration % print_per_iter == 0:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# # Continue Training Model

# %%
model_file = root_folder + "models/transformer_model2"

batch_size = 50
epochs = 10

iter_per_epoch = len(d_train) // batch_size
total_iterations = iter_per_epoch * epochs
print_per_iter = 10
eval_per_iter = 50
save_per_iter = 100

train_losses = np.load(root_folder + "models/transformer_model2_train_losses.npy").tolist()
val_losses = np.load(root_folder + "models/transformer_model2_val_losses.npy").tolist()
iterations = np.load(root_folder + "models/transformer_model2_iterations.npy").tolist()

with tf.Session() as sess:
    model.saver.restore(sess, model_file)
    print("Continue running for", total_iterations, "iterations")
    iteration = iterations[-1] + 1
    total_iterations = iteration + total_iterations - 1
    
    for epoch in range(1, epochs + 1):
        print("Epoch:", epoch)
        for _ in range(iter_per_epoch):
            batch_input, batch_input_mask, batch_output, batch_output_mask = build_batch(d_train, batch_size)
            feed = {model.source_sequence: batch_input, model.target_sequence: batch_output,
                              model.encoder_mask: batch_input_mask, model.decoder_mask: batch_output_mask}

            train_loss, _, step = sess.run([model.loss, model.train_op, model.global_step], feed_dict=feed)

            if iteration % print_per_iter == 0:
                print("Iteration {0} / {1}: Training loss - {2}".format(iteration, total_iterations, train_loss))

            if iteration % eval_per_iter == 0:
                batch_input, batch_input_mask, batch_output, batch_output_mask = build_batch(d_valid, batch_size)
                feed = {model.source_sequence: batch_input, model.target_sequence: batch_output,
                              model.encoder_mask: batch_input_mask, model.decoder_mask: batch_output_mask}
                eval_loss = sess.run(model.loss, feed_dict=feed)
                print("Evaluation loss:", eval_loss)
                val_losses.append(eval_loss)
                train_losses.append(train_loss)
                iterations.append(iteration)

                
            if iteration % save_per_iter == 0:
                model.saver.save(sess, model_file)
                np.save(root_folder + "models/transformer_model2_train_losses", np.array(train_losses))
                np.save(root_folder + "models/transformer_model2_val_losses", np.array(val_losses))
                np.save(root_folder + "models/transformer_model2_iterations", np.array(iterations))
                
            iteration += 1
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Project-Lion/models/transformer_model2
# Continue running for 10790 iterations
# Epoch: 1
# Iteration 6410 / 17190: Training loss - 3.782776355743408
# Iteration 6420 / 17190: Training loss - 4.295144557952881
# Iteration 6430 / 17190: Training loss - 4.331671714782715
# Iteration 6440 / 17190: Training loss - 4.373019218444824
# Iteration 6450 / 17190: Training loss - 3.984102725982666
# Evaluation loss: 5.158855
# Iteration 6460 / 17190: Training loss - 3.8757317066192627
# Iteration 6470 / 17190: Training loss - 4.490018844604492
# Iteration 6480 / 17190: Training loss - 4.005356311798096
# Iteration 6490 / 17190: Training loss - 3.5332772731781006
# Iteration 6500 / 17190: Training loss - 3.8157944679260254
# Evaluation loss: 4.338063
# Iteration 6510 / 17190: Training loss - 3.708214282989502
# Iteration 6520 / 17190: Training loss - 4.085648059844971
# Iteration 6530 / 17190: Training loss - 3.852739095687866
# Iteration 6540 / 17190: Training loss - 4.10938835144043
# Iteration 6550 / 17190: Training loss - 3.623724937438965
# Evaluation loss: 5.1104465
# Iteration 6560 / 17190: Training loss - 3.75864577293396
# Iteration 6570 / 17190: Training loss - 4.171273708343506
# Iteration 6580 / 17190: Training loss - 4.004984378814697
# Iteration 6590 / 17190: Training loss - 3.8541419506073
# Iteration 6600 / 17190: Training loss - 3.921442747116089
# Evaluation loss: 5.041904
# Iteration 6610 / 17190: Training loss - 4.372547149658203
# Iteration 6620 / 17190: Training loss - 4.154037952423096
# Iteration 6630 / 17190: Training loss - 3.6708426475524902
# Iteration 6640 / 17190: Training loss - 3.828155994415283
# Iteration 6650 / 17190: Training loss - 3.7631092071533203
# Evaluation loss: 4.7307444
# Iteration 6660 / 17190: Training loss - 3.8543708324432373
# Iteration 6670 / 17190: Training loss - 3.991929292678833
# Iteration 6680 / 17190: Training loss - 3.993143081665039
# Iteration 6690 / 17190: Training loss - 3.8460874557495117
# Iteration 6700 / 17190: Training loss - 4.4262542724609375
# Evaluation loss: 4.615316
# Iteration 6710 / 17190: Training loss - 4.114587783813477
# Iteration 6720 / 17190: Training loss - 3.927002429962158
# Iteration 6730 / 17190: Training loss - 4.128407955169678
# Iteration 6740 / 17190: Training loss - 4.073482990264893
# Iteration 6750 / 17190: Training loss - 3.769909143447876
# Evaluation loss: 4.9060645
# Iteration 6760 / 17190: Training loss - 3.795983076095581
# Iteration 6770 / 17190: Training loss - 3.9842445850372314
# Iteration 6780 / 17190: Training loss - 3.5184481143951416
# Iteration 6790 / 17190: Training loss - 3.701766014099121
# Iteration 6800 / 17190: Training loss - 4.120886325836182
# Evaluation loss: 4.547494
# Iteration 6810 / 17190: Training loss - 3.8581783771514893
# Iteration 6820 / 17190: Training loss - 3.8383071422576904
# Iteration 6830 / 17190: Training loss - 3.615143060684204
# Iteration 6840 / 17190: Training loss - 4.646503448486328
# Iteration 6850 / 17190: Training loss - 3.8433098793029785
# Evaluation loss: 4.7062287
# Iteration 6860 / 17190: Training loss - 3.5563673973083496
# Iteration 6870 / 17190: Training loss - 3.643444776535034
# Iteration 6880 / 17190: Training loss - 4.144411087036133
# Iteration 6890 / 17190: Training loss - 4.476676940917969
# Iteration 6900 / 17190: Training loss - 4.025959491729736
# Evaluation loss: 4.7121224
# Iteration 6910 / 17190: Training loss - 4.191683292388916
# Iteration 6920 / 17190: Training loss - 3.487689971923828
# Iteration 6930 / 17190: Training loss - 3.8776543140411377
# Iteration 6940 / 17190: Training loss - 3.5122058391571045
# Iteration 6950 / 17190: Training loss - 3.8712055683135986
# Evaluation loss: 4.7003164
# Iteration 6960 / 17190: Training loss - 3.9147727489471436
# Iteration 6970 / 17190: Training loss - 4.158975601196289
# Iteration 6980 / 17190: Training loss - 3.851024627685547
# Iteration 6990 / 17190: Training loss - 3.751582384109497
# Iteration 7000 / 17190: Training loss - 3.775989055633545
# Evaluation loss: 6.0217023
# Iteration 7010 / 17190: Training loss - 3.711777925491333
# Iteration 7020 / 17190: Training loss - 4.112659454345703
# Iteration 7030 / 17190: Training loss - 3.670837879180908
# Iteration 7040 / 17190: Training loss - 4.0231499671936035
# Iteration 7050 / 17190: Training loss - 3.897888422012329
# Evaluation loss: 5.2759485
# Iteration 7060 / 17190: Training loss - 3.331578016281128
# Iteration 7070 / 17190: Training loss - 3.411731004714966
# Iteration 7080 / 17190: Training loss - 3.7085845470428467
# Iteration 7090 / 17190: Training loss - 4.339882850646973
# Iteration 7100 / 17190: Training loss - 4.036549091339111
# Evaluation loss: 4.8253336
# Iteration 7110 / 17190: Training loss - 3.8679885864257812
# Iteration 7120 / 17190: Training loss - 4.105057239532471
# Iteration 7130 / 17190: Training loss - 3.953669786453247
# Iteration 7140 / 17190: Training loss - 3.5400242805480957
# Iteration 7150 / 17190: Training loss - 3.574704647064209
# Evaluation loss: 5.149507
# Iteration 7160 / 17190: Training loss - 4.199157238006592
# Iteration 7170 / 17190: Training loss - 3.8868777751922607
# Iteration 7180 / 17190: Training loss - 3.641042709350586
# Iteration 7190 / 17190: Training loss - 4.080331802368164
# Iteration 7200 / 17190: Training loss - 4.26712703704834
# Evaluation loss: 4.6147113
# Iteration 7210 / 17190: Training loss - 3.6993801593780518
# Iteration 7220 / 17190: Training loss - 3.2350916862487793
# Iteration 7230 / 17190: Training loss - 4.317282676696777
# Iteration 7240 / 17190: Training loss - 3.836089611053467
# Iteration 7250 / 17190: Training loss - 4.002407073974609
# Evaluation loss: 4.7291746
# Iteration 7260 / 17190: Training loss - 3.648486614227295
# Iteration 7270 / 17190: Training loss - 3.986935615539551
# Iteration 7280 / 17190: Training loss - 3.7815356254577637
# Iteration 7290 / 17190: Training loss - 3.9309279918670654
# Iteration 7300 / 17190: Training loss - 3.8828160762786865
# Evaluation loss: 4.915094
# Iteration 7310 / 17190: Training loss - 3.448169469833374
# Iteration 7320 / 17190: Training loss - 3.2534542083740234
# Iteration 7330 / 17190: Training loss - 3.5828990936279297
# Iteration 7340 / 17190: Training loss - 3.907606363296509
# Iteration 7350 / 17190: Training loss - 3.7796976566314697
# Evaluation loss: 4.918853
# Iteration 7360 / 17190: Training loss - 3.8217263221740723
# Iteration 7370 / 17190: Training loss - 4.111510276794434
# Iteration 7380 / 17190: Training loss - 3.5752768516540527
# Iteration 7390 / 17190: Training loss - 3.736198902130127
# Iteration 7400 / 17190: Training loss - 4.235937595367432
# Evaluation loss: 4.6452947
# Iteration 7410 / 17190: Training loss - 3.836864471435547
# Iteration 7420 / 17190: Training loss - 3.6416854858398438
# Iteration 7430 / 17190: Training loss - 3.6663155555725098
# Iteration 7440 / 17190: Training loss - 3.8506689071655273
# Iteration 7450 / 17190: Training loss - 3.6023342609405518
# Evaluation loss: 4.794815
# Iteration 7460 / 17190: Training loss - 3.806929111480713
# Iteration 7470 / 17190: Training loss - 3.699921131134033
# Epoch: 2
# Iteration 7480 / 17190: Training loss - 3.712183713912964
# Iteration 7490 / 17190: Training loss - 3.936091661453247
# Iteration 7500 / 17190: Training loss - 3.7097058296203613
# Evaluation loss: 4.201169
# Iteration 7510 / 17190: Training loss - 3.577437400817871
# Iteration 7520 / 17190: Training loss - 3.5896658897399902
# Iteration 7530 / 17190: Training loss - 3.97465443611145
# Iteration 7540 / 17190: Training loss - 4.028520584106445
# Iteration 7550 / 17190: Training loss - 3.716796875
# Evaluation loss: 4.9832854
# Iteration 7560 / 17190: Training loss - 3.4379215240478516
# Iteration 7570 / 17190: Training loss - 4.138979434967041
# Iteration 7580 / 17190: Training loss - 3.6333351135253906
# Iteration 7590 / 17190: Training loss - 4.234165191650391
# Iteration 7600 / 17190: Training loss - 3.910412311553955
# Evaluation loss: 4.076141
# Iteration 7610 / 17190: Training loss - 4.332909107208252
# Iteration 7620 / 17190: Training loss - 3.7179479598999023
# Iteration 7630 / 17190: Training loss - 3.5606515407562256
# Iteration 7640 / 17190: Training loss - 3.6759941577911377
# Iteration 7650 / 17190: Training loss - 3.9237775802612305
# Evaluation loss: 4.705116
# Iteration 7660 / 17190: Training loss - 3.895738124847412
# Iteration 7670 / 17190: Training loss - 3.595857620239258
# Iteration 7680 / 17190: Training loss - 4.17924690246582
# Iteration 7690 / 17190: Training loss - 3.7019708156585693
# Iteration 7700 / 17190: Training loss - 3.864462375640869
# Evaluation loss: 4.600863
# Iteration 7710 / 17190: Training loss - 3.4702088832855225
# Iteration 7720 / 17190: Training loss - 3.690419912338257
# Iteration 7730 / 17190: Training loss - 3.690978765487671
# Iteration 7740 / 17190: Training loss - 4.047534465789795
# Iteration 7750 / 17190: Training loss - 4.401905059814453
# Evaluation loss: 4.5836086
# Iteration 7760 / 17190: Training loss - 4.128967761993408
# Iteration 7770 / 17190: Training loss - 3.5203757286071777
# Iteration 7780 / 17190: Training loss - 3.928060531616211
# Iteration 7790 / 17190: Training loss - 3.8762190341949463
# Iteration 7800 / 17190: Training loss - 4.390003204345703
# Evaluation loss: 4.918882
# Iteration 7810 / 17190: Training loss - 4.0111165046691895
# Iteration 7820 / 17190: Training loss - 3.6456949710845947
# Iteration 7830 / 17190: Training loss - 3.933067798614502
# Iteration 7840 / 17190: Training loss - 4.011224746704102
# Iteration 7850 / 17190: Training loss - 3.757133960723877
# Evaluation loss: 4.6241627
# Iteration 7860 / 17190: Training loss - 4.018508434295654
# Iteration 7870 / 17190: Training loss - 3.652116060256958
# Iteration 7880 / 17190: Training loss - 3.6937012672424316
# Iteration 7890 / 17190: Training loss - 3.941096305847168
# Iteration 7900 / 17190: Training loss - 3.8351898193359375
# Evaluation loss: 4.534039
# Iteration 7910 / 17190: Training loss - 4.066282749176025
# Iteration 7920 / 17190: Training loss - 3.901599884033203
# Iteration 7930 / 17190: Training loss - 3.326770544052124
# Iteration 7940 / 17190: Training loss - 3.79860258102417
# Iteration 7950 / 17190: Training loss - 3.742790699005127
# Evaluation loss: 4.6455116
# Iteration 7960 / 17190: Training loss - 3.769289255142212
# Iteration 7970 / 17190: Training loss - 4.1037983894348145
# Iteration 7980 / 17190: Training loss - 3.615363597869873
# Iteration 7990 / 17190: Training loss - 4.04539155960083
# Iteration 8000 / 17190: Training loss - 4.023834705352783
# Evaluation loss: 4.5507765
# Iteration 8010 / 17190: Training loss - 3.7320704460144043
# Iteration 8020 / 17190: Training loss - 3.9729557037353516
# Iteration 8030 / 17190: Training loss - 3.5851733684539795
# Iteration 8040 / 17190: Training loss - 3.8573949337005615
# Iteration 8050 / 17190: Training loss - 3.3709664344787598
# Evaluation loss: 4.826979
# Iteration 8060 / 17190: Training loss - 3.8475098609924316
# Iteration 8070 / 17190: Training loss - 4.215305805206299
# Iteration 8080 / 17190: Training loss - 3.94469952583313
# Iteration 8090 / 17190: Training loss - 3.4910383224487305
# Iteration 8100 / 17190: Training loss - 4.314512729644775
# Evaluation loss: 4.3062787
# Iteration 8110 / 17190: Training loss - 3.833489418029785
# Iteration 8120 / 17190: Training loss - 4.262676239013672
# Iteration 8130 / 17190: Training loss - 3.8940348625183105
# Iteration 8140 / 17190: Training loss - 3.7421364784240723
# Iteration 8150 / 17190: Training loss - 3.9494452476501465
# Evaluation loss: 4.3139954
# Iteration 8160 / 17190: Training loss - 3.4702565670013428
# Iteration 8170 / 17190: Training loss - 3.9138965606689453
# Iteration 8180 / 17190: Training loss - 3.661086082458496
# Iteration 8190 / 17190: Training loss - 3.412022829055786
# Iteration 8200 / 17190: Training loss - 3.5294322967529297
# Evaluation loss: 5.103694
# Iteration 8210 / 17190: Training loss - 3.8996963500976562
# Iteration 8220 / 17190: Training loss - 3.736043930053711
# Iteration 8230 / 17190: Training loss - 3.3998444080352783
# Iteration 8240 / 17190: Training loss - 4.144432067871094
# Iteration 8250 / 17190: Training loss - 3.5453665256500244
# Evaluation loss: 4.758665
# Iteration 8260 / 17190: Training loss - 3.522362470626831
# Iteration 8270 / 17190: Training loss - 3.8682563304901123
# Iteration 8280 / 17190: Training loss - 3.7259719371795654
# Iteration 8290 / 17190: Training loss - 4.06322717666626
# Iteration 8300 / 17190: Training loss - 3.740027904510498
# Evaluation loss: 5.0928764
# Iteration 8310 / 17190: Training loss - 3.769613742828369
# Iteration 8320 / 17190: Training loss - 3.591714382171631
# Iteration 8330 / 17190: Training loss - 3.814283609390259
# Iteration 8340 / 17190: Training loss - 3.92958927154541
# Iteration 8350 / 17190: Training loss - 3.70794677734375
# Evaluation loss: 4.09904
# Iteration 8360 / 17190: Training loss - 3.26520037651062
# Iteration 8370 / 17190: Training loss - 4.159346103668213
# Iteration 8380 / 17190: Training loss - 4.432676315307617
# Iteration 8390 / 17190: Training loss - 3.8616080284118652
# Iteration 8400 / 17190: Training loss - 3.3071107864379883
# Evaluation loss: 4.74538
# Iteration 8410 / 17190: Training loss - 4.0713419914245605
# Iteration 8420 / 17190: Training loss - 4.150379657745361
# Iteration 8430 / 17190: Training loss - 3.5591156482696533
# Iteration 8440 / 17190: Training loss - 3.9086241722106934
# Iteration 8450 / 17190: Training loss - 3.4121127128601074
# Evaluation loss: 4.0586014
# Iteration 8460 / 17190: Training loss - 3.3205251693725586
# Iteration 8470 / 17190: Training loss - 3.7177460193634033
# Iteration 8480 / 17190: Training loss - 4.005764961242676
# Iteration 8490 / 17190: Training loss - 3.9233973026275635
# Iteration 8500 / 17190: Training loss - 3.7944912910461426
# Evaluation loss: 3.9195008
# Iteration 8510 / 17190: Training loss - 3.7657830715179443
# Iteration 8520 / 17190: Training loss - 3.8584463596343994
# Iteration 8530 / 17190: Training loss - 3.8484208583831787
# Iteration 8540 / 17190: Training loss - 4.08373498916626
# Iteration 8550 / 17190: Training loss - 3.2287046909332275
# Evaluation loss: 4.616213
# Epoch: 3
# Iteration 8560 / 17190: Training loss - 3.1816256046295166
# Iteration 8570 / 17190: Training loss - 3.2384209632873535
# Iteration 8580 / 17190: Training loss - 3.693328857421875
# Iteration 8590 / 17190: Training loss - 3.595778465270996
# Iteration 8600 / 17190: Training loss - 3.466872215270996
# Evaluation loss: 4.6537304
# Iteration 8610 / 17190: Training loss - 4.188620090484619
# Iteration 8620 / 17190: Training loss - 3.886462450027466
# Iteration 8630 / 17190: Training loss - 3.4548397064208984
# Iteration 8640 / 17190: Training loss - 3.5869874954223633
# Iteration 8650 / 17190: Training loss - 3.8019561767578125
# Evaluation loss: 4.7049565
# Iteration 8660 / 17190: Training loss - 3.3921713829040527
# Iteration 8670 / 17190: Training loss - 3.4482967853546143
# Iteration 8680 / 17190: Training loss - 3.8346893787384033
# Iteration 8690 / 17190: Training loss - 3.551359176635742
# Iteration 8700 / 17190: Training loss - 3.357043743133545
# Evaluation loss: 4.702301
# Iteration 8710 / 17190: Training loss - 3.944902181625366
# Iteration 8720 / 17190: Training loss - 4.053181171417236
# Iteration 8730 / 17190: Training loss - 3.7907238006591797
# Iteration 8740 / 17190: Training loss - 3.613722324371338
# Iteration 8750 / 17190: Training loss - 3.674177885055542
# Evaluation loss: 5.0265574
# Iteration 8760 / 17190: Training loss - 3.8961119651794434
# Iteration 8770 / 17190: Training loss - 3.571129322052002
# Iteration 8780 / 17190: Training loss - 3.6046223640441895
# Iteration 8790 / 17190: Training loss - 3.8155696392059326
# Iteration 8800 / 17190: Training loss - 3.5707406997680664
# Evaluation loss: 5.0163856
# Iteration 8810 / 17190: Training loss - 3.886220932006836
# Iteration 8820 / 17190: Training loss - 3.4924168586730957
# Iteration 8830 / 17190: Training loss - 3.4149837493896484
# Iteration 8840 / 17190: Training loss - 3.80226731300354
# Iteration 8850 / 17190: Training loss - 3.6114230155944824
# Evaluation loss: 5.2465253
# Iteration 8860 / 17190: Training loss - 3.6700613498687744
# Iteration 8870 / 17190: Training loss - 3.53351092338562
# Iteration 8880 / 17190: Training loss - 3.9595086574554443
# Iteration 8890 / 17190: Training loss - 3.8108224868774414
# Iteration 8900 / 17190: Training loss - 3.770456075668335
# Evaluation loss: 4.6107016
# Iteration 8910 / 17190: Training loss - 3.7042136192321777
# Iteration 8920 / 17190: Training loss - 3.6207520961761475
# Iteration 8930 / 17190: Training loss - 3.460082530975342
# Iteration 8940 / 17190: Training loss - 3.7804172039031982
# Iteration 8950 / 17190: Training loss - 3.798940896987915
# Evaluation loss: 4.8881726
# Iteration 8960 / 17190: Training loss - 3.320432424545288
# Iteration 8970 / 17190: Training loss - 3.910281181335449
# Iteration 8980 / 17190: Training loss - 3.4204819202423096
# Iteration 8990 / 17190: Training loss - 3.6831212043762207
# Iteration 9000 / 17190: Training loss - 3.586714744567871
# Evaluation loss: 4.796678
# Iteration 9010 / 17190: Training loss - 3.7472381591796875
# Iteration 9020 / 17190: Training loss - 3.6329309940338135
# Iteration 9030 / 17190: Training loss - 3.403817653656006
# Iteration 9040 / 17190: Training loss - 3.1356284618377686
# Iteration 9050 / 17190: Training loss - 3.763080358505249
# Evaluation loss: 4.795511
# Iteration 9060 / 17190: Training loss - 3.8936331272125244
# Iteration 9070 / 17190: Training loss - 3.986532211303711
# Iteration 9080 / 17190: Training loss - 3.790234327316284
# Iteration 9090 / 17190: Training loss - 3.343022346496582
# Iteration 9100 / 17190: Training loss - 3.2970621585845947
# Evaluation loss: 4.854978
# Iteration 9110 / 17190: Training loss - 3.700389862060547
# Iteration 9120 / 17190: Training loss - 3.2952194213867188
# Iteration 9130 / 17190: Training loss - 3.128120183944702
# Iteration 9140 / 17190: Training loss - 4.105138778686523
# Iteration 9150 / 17190: Training loss - 3.9284565448760986
# Evaluation loss: 4.9571576
# Iteration 9160 / 17190: Training loss - 3.3199210166931152
# Iteration 9170 / 17190: Training loss - 3.879179000854492
# Iteration 9180 / 17190: Training loss - 3.8926713466644287
# Iteration 9190 / 17190: Training loss - 3.2027292251586914
# Iteration 9200 / 17190: Training loss - 3.72908878326416
# Evaluation loss: 4.564743
# Iteration 9210 / 17190: Training loss - 4.259345054626465
# Iteration 9220 / 17190: Training loss - 3.7222259044647217
# Iteration 9230 / 17190: Training loss - 3.7765402793884277
# Iteration 9240 / 17190: Training loss - 3.735286235809326
# Iteration 9250 / 17190: Training loss - 3.761302947998047
# Evaluation loss: 4.9715233
# Iteration 9260 / 17190: Training loss - 3.2653515338897705
# Iteration 9270 / 17190: Training loss - 3.4670913219451904
# Iteration 9280 / 17190: Training loss - 3.884835958480835
# Iteration 9290 / 17190: Training loss - 3.5546412467956543
# Iteration 9300 / 17190: Training loss - 3.7380003929138184
# Evaluation loss: 4.909203
# Iteration 9310 / 17190: Training loss - 3.4912607669830322
# Iteration 9320 / 17190: Training loss - 3.408583879470825
# Iteration 9330 / 17190: Training loss - 3.560856342315674
# Iteration 9340 / 17190: Training loss - 3.864348888397217
# Iteration 9350 / 17190: Training loss - 3.656259059906006
# Evaluation loss: 4.7040486
# Iteration 9360 / 17190: Training loss - 3.6516687870025635
# Iteration 9370 / 17190: Training loss - 3.425025224685669
# Iteration 9380 / 17190: Training loss - 3.3680381774902344
# Iteration 9390 / 17190: Training loss - 3.8519363403320312
# Iteration 9400 / 17190: Training loss - 3.558453321456909
# Evaluation loss: 4.8655496
# Iteration 9410 / 17190: Training loss - 3.574599504470825
# Iteration 9420 / 17190: Training loss - 3.599818706512451
# Iteration 9430 / 17190: Training loss - 4.048943519592285
# Iteration 9440 / 17190: Training loss - 3.0010805130004883
# Iteration 9450 / 17190: Training loss - 3.374119520187378
# Evaluation loss: 5.2309475
# Iteration 9460 / 17190: Training loss - 3.347882032394409
# Iteration 9470 / 17190: Training loss - 3.4751720428466797
# Iteration 9480 / 17190: Training loss - 3.5320236682891846
# Iteration 9490 / 17190: Training loss - 3.8100717067718506
# Iteration 9500 / 17190: Training loss - 3.315093517303467
# Evaluation loss: 4.555659
# Iteration 9510 / 17190: Training loss - 3.4189884662628174
# Iteration 9520 / 17190: Training loss - 3.6892194747924805
# Iteration 9530 / 17190: Training loss - 3.7630414962768555
# Iteration 9540 / 17190: Training loss - 3.547687292098999
# Iteration 9550 / 17190: Training loss - 4.097311019897461
# Evaluation loss: 4.7094812
# Iteration 9560 / 17190: Training loss - 3.0210115909576416
# Iteration 9570 / 17190: Training loss - 4.068840980529785
# Iteration 9580 / 17190: Training loss - 3.6555776596069336
# Iteration 9590 / 17190: Training loss - 3.8276760578155518
# Iteration 9600 / 17190: Training loss - 3.60683536529541
# Evaluation loss: 4.2498507
# Iteration 9610 / 17190: Training loss - 3.895442485809326
# Iteration 9620 / 17190: Training loss - 3.6835381984710693
# Iteration 9630 / 17190: Training loss - 3.5064194202423096
# Epoch: 4
# Iteration 9640 / 17190: Training loss - 4.017940044403076
# Iteration 9650 / 17190: Training loss - 3.4427857398986816
# Evaluation loss: 5.021178
# Iteration 9660 / 17190: Training loss - 3.6091904640197754
# Iteration 9670 / 17190: Training loss - 3.117014169692993
# Iteration 9680 / 17190: Training loss - 3.7647643089294434
# Iteration 9690 / 17190: Training loss - 3.8383255004882812
# Iteration 9700 / 17190: Training loss - 3.4451684951782227
# Evaluation loss: 4.846595
# Iteration 9710 / 17190: Training loss - 3.6675047874450684
# Iteration 9720 / 17190: Training loss - 3.234363555908203
# Iteration 9730 / 17190: Training loss - 3.4016449451446533
# Iteration 9740 / 17190: Training loss - 3.72696852684021
# Iteration 9750 / 17190: Training loss - 4.242358207702637
# Evaluation loss: 4.949387
# Iteration 9760 / 17190: Training loss - 3.750312328338623
# Iteration 9770 / 17190: Training loss - 3.4346256256103516
# Iteration 9780 / 17190: Training loss - 3.4969406127929688
# Iteration 9790 / 17190: Training loss - 3.9367966651916504
# Iteration 9800 / 17190: Training loss - 3.1738874912261963
# Evaluation loss: 4.6334457
# Iteration 9810 / 17190: Training loss - 3.5548794269561768
# Iteration 9820 / 17190: Training loss - 3.4678127765655518
# Iteration 9830 / 17190: Training loss - 3.6704354286193848
# Iteration 9840 / 17190: Training loss - 4.150079727172852
# Iteration 9850 / 17190: Training loss - 3.3575854301452637
# Evaluation loss: 4.8608255
# Iteration 9860 / 17190: Training loss - 3.599193572998047
# Iteration 9870 / 17190: Training loss - 3.0417609214782715
# Iteration 9880 / 17190: Training loss - 3.5262084007263184
# Iteration 9890 / 17190: Training loss - 4.103893756866455
# Iteration 9900 / 17190: Training loss - 3.4751620292663574
# Evaluation loss: 4.700211
# Iteration 9910 / 17190: Training loss - 3.3831136226654053
# Iteration 9920 / 17190: Training loss - 3.7279751300811768
# Iteration 9930 / 17190: Training loss - 3.688089370727539
# Iteration 9940 / 17190: Training loss - 3.610983371734619
# Iteration 9950 / 17190: Training loss - 3.9124159812927246
# Evaluation loss: 4.904143
# Iteration 9960 / 17190: Training loss - 3.2955801486968994
# Iteration 9970 / 17190: Training loss - 3.189377546310425
# Iteration 9980 / 17190: Training loss - 3.330552816390991
# Iteration 9990 / 17190: Training loss - 3.100773811340332
# Iteration 10000 / 17190: Training loss - 3.5082147121429443
# Evaluation loss: 4.3151298
# Iteration 10010 / 17190: Training loss - 3.5399420261383057
# Iteration 10020 / 17190: Training loss - 3.5992865562438965
# Iteration 10030 / 17190: Training loss - 3.5240416526794434
# Iteration 10040 / 17190: Training loss - 3.43068528175354
# Iteration 10050 / 17190: Training loss - 3.273261070251465
# Evaluation loss: 5.3045177
# Iteration 10060 / 17190: Training loss - 3.3525760173797607
# Iteration 10070 / 17190: Training loss - 3.5278267860412598
# Iteration 10080 / 17190: Training loss - 3.600156784057617
# Iteration 10090 / 17190: Training loss - 3.389049768447876
# Iteration 10100 / 17190: Training loss - 3.2158288955688477
# Evaluation loss: 4.720025
# Iteration 10110 / 17190: Training loss - 3.2781193256378174
# Iteration 10120 / 17190: Training loss - 3.5727007389068604
# Iteration 10130 / 17190: Training loss - 3.7653181552886963
# Iteration 10140 / 17190: Training loss - 3.4803473949432373
# Iteration 10150 / 17190: Training loss - 4.163457870483398
# Evaluation loss: 4.8161674
# Iteration 10160 / 17190: Training loss - 3.2571728229522705
# Iteration 10170 / 17190: Training loss - 3.8904876708984375
# Iteration 10180 / 17190: Training loss - 3.7272837162017822
# Iteration 10190 / 17190: Training loss - 3.283808708190918
# Iteration 10200 / 17190: Training loss - 3.677018642425537
# Evaluation loss: 4.963765
# Iteration 10210 / 17190: Training loss - 3.549764394760132
# Iteration 10220 / 17190: Training loss - 3.182431221008301
# Iteration 10230 / 17190: Training loss - 3.833421230316162
# Iteration 10240 / 17190: Training loss - 3.3874728679656982
# Iteration 10250 / 17190: Training loss - 3.864630699157715
# Evaluation loss: 4.9058356
# Iteration 10260 / 17190: Training loss - 3.426970958709717
# Iteration 10270 / 17190: Training loss - 3.4636948108673096
# Iteration 10280 / 17190: Training loss - 3.463061809539795
# Iteration 10290 / 17190: Training loss - 3.3422300815582275
# Iteration 10300 / 17190: Training loss - 3.967292308807373
# Evaluation loss: 5.1682053
# Iteration 10310 / 17190: Training loss - 3.608154296875
# Iteration 10320 / 17190: Training loss - 3.4961326122283936
# Iteration 10330 / 17190: Training loss - 3.829219341278076
# Iteration 10340 / 17190: Training loss - 3.992666721343994
# Iteration 10350 / 17190: Training loss - 3.110539197921753
# Evaluation loss: 4.829208
# Iteration 10360 / 17190: Training loss - 3.266134023666382
# Iteration 10370 / 17190: Training loss - 4.08070707321167
# Iteration 10380 / 17190: Training loss - 3.0901284217834473
# Iteration 10390 / 17190: Training loss - 3.437349319458008
# Iteration 10400 / 17190: Training loss - 3.1504926681518555
# Evaluation loss: 4.5623813
# Iteration 10410 / 17190: Training loss - 3.904994487762451
# Iteration 10420 / 17190: Training loss - 3.329875946044922
# Iteration 10430 / 17190: Training loss - 3.3304948806762695
# Iteration 10440 / 17190: Training loss - 3.434238910675049
# Iteration 10450 / 17190: Training loss - 3.475797653198242
# Evaluation loss: 4.8508453
# Iteration 10460 / 17190: Training loss - 3.3705291748046875
# Iteration 10470 / 17190: Training loss - 3.150324583053589
# Iteration 10480 / 17190: Training loss - 3.3710501194000244
# Iteration 10490 / 17190: Training loss - 2.833012819290161
# Iteration 10500 / 17190: Training loss - 2.7855184078216553
# Evaluation loss: 4.6653414
# Iteration 10510 / 17190: Training loss - 3.8893816471099854
# Iteration 10520 / 17190: Training loss - 3.712400197982788
# Iteration 10530 / 17190: Training loss - 3.5867013931274414
# Iteration 10540 / 17190: Training loss - 3.358927011489868
# Iteration 10550 / 17190: Training loss - 3.4306864738464355
# Evaluation loss: 4.785178
# Iteration 10560 / 17190: Training loss - 3.5932958126068115
# Iteration 10570 / 17190: Training loss - 3.271162509918213
# Iteration 10580 / 17190: Training loss - 3.527218818664551
# Iteration 10590 / 17190: Training loss - 3.462339162826538
# Iteration 10600 / 17190: Training loss - 3.3844902515411377
# Evaluation loss: 4.6424503
# Iteration 10610 / 17190: Training loss - 2.9104583263397217
# Iteration 10620 / 17190: Training loss - 3.1854264736175537
# Iteration 10630 / 17190: Training loss - 3.461698532104492
# Iteration 10640 / 17190: Training loss - 3.4945662021636963
# Iteration 10650 / 17190: Training loss - 3.284468412399292
# Evaluation loss: 5.1465216
# Iteration 10660 / 17190: Training loss - 3.3571560382843018
# Iteration 10670 / 17190: Training loss - 3.6052560806274414
# Iteration 10680 / 17190: Training loss - 3.1624741554260254
# Iteration 10690 / 17190: Training loss - 3.6794354915618896
# Iteration 10700 / 17190: Training loss - 3.7468860149383545
# Evaluation loss: 4.5048013
# Iteration 10710 / 17190: Training loss - 3.6723814010620117
# Epoch: 5
# Iteration 10720 / 17190: Training loss - 3.1427698135375977
# Iteration 10730 / 17190: Training loss - 3.6904942989349365
# Iteration 10740 / 17190: Training loss - 2.690782308578491
# Iteration 10750 / 17190: Training loss - 3.662323474884033
# Evaluation loss: 4.625912
# Iteration 10760 / 17190: Training loss - 3.8337438106536865
# Iteration 10770 / 17190: Training loss - 3.683715343475342
# Iteration 10780 / 17190: Training loss - 3.430248260498047
# Iteration 10790 / 17190: Training loss - 3.8630197048187256
# Iteration 10800 / 17190: Training loss - 3.4411725997924805
# Evaluation loss: 4.9703536
# Iteration 10810 / 17190: Training loss - 3.736077308654785
# Iteration 10820 / 17190: Training loss - 3.218221426010132
# Iteration 10830 / 17190: Training loss - 3.9998056888580322
# Iteration 10840 / 17190: Training loss - 3.83617901802063
# Iteration 10850 / 17190: Training loss - 3.0160531997680664
# Evaluation loss: 4.8930016
# Iteration 10860 / 17190: Training loss - 3.420990228652954
# Iteration 10870 / 17190: Training loss - 3.437249183654785
# Iteration 10880 / 17190: Training loss - 3.5087809562683105
# Iteration 10890 / 17190: Training loss - 3.364285707473755
# Iteration 10900 / 17190: Training loss - 2.9218671321868896
# Evaluation loss: 4.454194
# Iteration 10910 / 17190: Training loss - 3.4124672412872314
# Iteration 10920 / 17190: Training loss - 3.4314136505126953
# Iteration 10930 / 17190: Training loss - 4.100981712341309
# Iteration 10940 / 17190: Training loss - 3.183858633041382
# Iteration 10950 / 17190: Training loss - 3.491715669631958
# Evaluation loss: 3.629775
# Iteration 10960 / 17190: Training loss - 3.7139174938201904
# Iteration 10970 / 17190: Training loss - 3.6858458518981934
# Iteration 10980 / 17190: Training loss - 3.032003164291382
# Iteration 10990 / 17190: Training loss - 3.30956768989563
# Iteration 11000 / 17190: Training loss - 3.732154607772827
# Evaluation loss: 4.9227943
# Iteration 11010 / 17190: Training loss - 3.425417184829712
# Iteration 11020 / 17190: Training loss - 3.8607563972473145
# Iteration 11030 / 17190: Training loss - 3.7890920639038086
# Iteration 11040 / 17190: Training loss - 3.4778623580932617
# Iteration 11050 / 17190: Training loss - 3.9141433238983154
# Evaluation loss: 4.8776355
# Iteration 11060 / 17190: Training loss - 3.0514793395996094
# Iteration 11070 / 17190: Training loss - 3.0310964584350586
# Iteration 11080 / 17190: Training loss - 3.297816514968872
# Iteration 11090 / 17190: Training loss - 3.382972002029419
# Iteration 11100 / 17190: Training loss - 3.1593918800354004
# Evaluation loss: 4.4603987
# Iteration 11110 / 17190: Training loss - 3.049896001815796
# Iteration 11120 / 17190: Training loss - 3.4616146087646484
# Iteration 11130 / 17190: Training loss - 3.468596935272217
# Iteration 11140 / 17190: Training loss - 3.234071731567383
# Iteration 11150 / 17190: Training loss - 3.6633546352386475
# Evaluation loss: 4.6473494
# Iteration 11160 / 17190: Training loss - 3.8033394813537598
# Iteration 11170 / 17190: Training loss - 3.1585283279418945
# Iteration 11180 / 17190: Training loss - 3.872746229171753
# Iteration 11190 / 17190: Training loss - 3.0225532054901123
# Iteration 11200 / 17190: Training loss - 2.8980491161346436
# Evaluation loss: 4.6608124
# Iteration 11210 / 17190: Training loss - 3.010566234588623
# Iteration 11220 / 17190: Training loss - 3.649285316467285
# Iteration 11230 / 17190: Training loss - 3.1794862747192383
# Iteration 11240 / 17190: Training loss - 2.8810808658599854
# Iteration 11250 / 17190: Training loss - 2.5876004695892334
# Evaluation loss: 4.5156364
# Iteration 11260 / 17190: Training loss - 3.2503888607025146
# Iteration 11270 / 17190: Training loss - 3.1848745346069336
# Iteration 11280 / 17190: Training loss - 3.036379098892212
# Iteration 11290 / 17190: Training loss - 3.361884593963623
# Iteration 11300 / 17190: Training loss - 3.5710206031799316
# Evaluation loss: 5.032939
# Iteration 11310 / 17190: Training loss - 3.3460404872894287
# Iteration 11320 / 17190: Training loss - 3.9415242671966553
# Iteration 11330 / 17190: Training loss - 3.2363946437835693
# Iteration 11340 / 17190: Training loss - 2.898284435272217
# Iteration 11350 / 17190: Training loss - 3.2141425609588623
# Evaluation loss: 4.322812
# Iteration 11360 / 17190: Training loss - 3.4803802967071533
# Iteration 11370 / 17190: Training loss - 2.819702386856079
# Iteration 11380 / 17190: Training loss - 2.900430679321289
# Iteration 11390 / 17190: Training loss - 2.9734244346618652
# Iteration 11400 / 17190: Training loss - 3.033754825592041
# Evaluation loss: 5.0195007
# Iteration 11410 / 17190: Training loss - 2.7668778896331787
# Iteration 11420 / 17190: Training loss - 4.002561569213867
# Iteration 11430 / 17190: Training loss - 3.2729904651641846
# Iteration 11440 / 17190: Training loss - 3.4018397331237793
# Iteration 11450 / 17190: Training loss - 3.228224277496338
# Evaluation loss: 5.23926
# Iteration 11460 / 17190: Training loss - 3.0166420936584473
# Iteration 11470 / 17190: Training loss - 3.835754871368408
# Iteration 11480 / 17190: Training loss - 3.547619104385376
# Iteration 11490 / 17190: Training loss - 3.583031415939331
# Iteration 11500 / 17190: Training loss - 3.635826349258423
# Evaluation loss: 4.838231
# Iteration 11510 / 17190: Training loss - 3.3308303356170654
# Iteration 11520 / 17190: Training loss - 4.106467247009277
# Iteration 11530 / 17190: Training loss - 3.40873384475708
# Iteration 11540 / 17190: Training loss - 3.2644991874694824
# Iteration 11550 / 17190: Training loss - 2.7965638637542725
# Evaluation loss: 4.7443066
# Iteration 11560 / 17190: Training loss - 3.3728256225585938
# Iteration 11570 / 17190: Training loss - 3.4781980514526367
# Iteration 11580 / 17190: Training loss - 3.1760427951812744
# Iteration 11590 / 17190: Training loss - 3.3307981491088867
# Iteration 11600 / 17190: Training loss - 3.4557132720947266
# Evaluation loss: 4.908137
# Iteration 11610 / 17190: Training loss - 3.115896701812744
# Iteration 11620 / 17190: Training loss - 3.5898630619049072
# Iteration 11630 / 17190: Training loss - 3.326066732406616
# Iteration 11640 / 17190: Training loss - 3.2158403396606445
# Iteration 11650 / 17190: Training loss - 3.4118685722351074
# Evaluation loss: 3.8471837
# Iteration 11660 / 17190: Training loss - 3.6021697521209717
# Iteration 11670 / 17190: Training loss - 3.285573959350586
# Iteration 11680 / 17190: Training loss - 3.441793203353882
# Iteration 11690 / 17190: Training loss - 2.820469617843628
# Iteration 11700 / 17190: Training loss - 3.5334784984588623
# Evaluation loss: 4.720334
# Iteration 11710 / 17190: Training loss - 3.3698883056640625
# Iteration 11720 / 17190: Training loss - 3.1176435947418213
# Iteration 11730 / 17190: Training loss - 3.225503444671631
# Iteration 11740 / 17190: Training loss - 3.6199774742126465
# Iteration 11750 / 17190: Training loss - 3.00521183013916
# Evaluation loss: 4.206437
# Iteration 11760 / 17190: Training loss - 2.7726926803588867
# Iteration 11770 / 17190: Training loss - 2.8562276363372803
# Iteration 11780 / 17190: Training loss - 3.5549216270446777
# Iteration 11790 / 17190: Training loss - 3.375375270843506
# Epoch: 6
# Iteration 11800 / 17190: Training loss - 3.7475671768188477
# Evaluation loss: 4.663774
# Iteration 11810 / 17190: Training loss - 3.3046553134918213
# Iteration 11820 / 17190: Training loss - 3.3415215015411377
# Iteration 11830 / 17190: Training loss - 3.459019899368286
# Iteration 11840 / 17190: Training loss - 3.5837457180023193
# Iteration 11850 / 17190: Training loss - 3.1761064529418945
# Evaluation loss: 4.9363327
# Iteration 11860 / 17190: Training loss - 3.2875161170959473
# Iteration 11870 / 17190: Training loss - 3.4469854831695557
# Iteration 11880 / 17190: Training loss - 3.3940014839172363
# Iteration 11890 / 17190: Training loss - 3.5616743564605713
# Iteration 11900 / 17190: Training loss - 3.2362403869628906
# Evaluation loss: 4.8873878
# Iteration 11910 / 17190: Training loss - 2.9491491317749023
# Iteration 11920 / 17190: Training loss - 3.59903883934021
# Iteration 11930 / 17190: Training loss - 3.547819137573242
# Iteration 11940 / 17190: Training loss - 3.2873477935791016
# Iteration 11950 / 17190: Training loss - 3.648792266845703
# Evaluation loss: 5.014241
# Iteration 11960 / 17190: Training loss - 2.855520248413086
# Iteration 11970 / 17190: Training loss - 3.3484015464782715
# Iteration 11980 / 17190: Training loss - 3.5778679847717285
# Iteration 11990 / 17190: Training loss - 3.439171552658081
# Iteration 12000 / 17190: Training loss - 3.442505121231079
# Evaluation loss: 4.8163795
# Iteration 12010 / 17190: Training loss - 3.274868965148926
# Iteration 12020 / 17190: Training loss - 3.0829174518585205
# Iteration 12030 / 17190: Training loss - 3.0784897804260254
# Iteration 12040 / 17190: Training loss - 3.0460128784179688
# Iteration 12050 / 17190: Training loss - 3.2418506145477295
# Evaluation loss: 5.246281
# Iteration 12060 / 17190: Training loss - 3.239359140396118
# Iteration 12070 / 17190: Training loss - 3.114973783493042
# Iteration 12080 / 17190: Training loss - 2.944247007369995
# Iteration 12090 / 17190: Training loss - 3.4404003620147705
# Iteration 12100 / 17190: Training loss - 3.6621882915496826
# Evaluation loss: 4.570978
# Iteration 12110 / 17190: Training loss - 3.4567081928253174
# Iteration 12120 / 17190: Training loss - 3.146909475326538
# Iteration 12130 / 17190: Training loss - 3.023998975753784
# Iteration 12140 / 17190: Training loss - 3.0944690704345703
# Iteration 12150 / 17190: Training loss - 3.476151704788208
# Evaluation loss: 5.1000195
# Iteration 12160 / 17190: Training loss - 2.7884936332702637
# Iteration 12170 / 17190: Training loss - 3.2576656341552734
# Iteration 12180 / 17190: Training loss - 3.32000470161438
# Iteration 12190 / 17190: Training loss - 3.038055181503296
# Iteration 12200 / 17190: Training loss - 3.0851335525512695
# Evaluation loss: 4.7309933
# Iteration 12210 / 17190: Training loss - 2.760098695755005
# Iteration 12220 / 17190: Training loss - 3.5860424041748047
# Iteration 12230 / 17190: Training loss - 3.0298354625701904
# Iteration 12240 / 17190: Training loss - 3.1307380199432373
# Iteration 12250 / 17190: Training loss - 3.0269243717193604
# Evaluation loss: 5.1317606
# Iteration 12260 / 17190: Training loss - 3.5285987854003906
# Iteration 12270 / 17190: Training loss - 2.8803675174713135
# Iteration 12280 / 17190: Training loss - 2.909552812576294
# Iteration 12290 / 17190: Training loss - 3.2751388549804688
# Iteration 12300 / 17190: Training loss - 3.194387912750244
# Evaluation loss: 4.8156943
# Iteration 12310 / 17190: Training loss - 3.02736759185791
# Iteration 12320 / 17190: Training loss - 3.4764404296875
# Iteration 12330 / 17190: Training loss - 3.00734543800354
# Iteration 12340 / 17190: Training loss - 3.0258545875549316
# Iteration 12350 / 17190: Training loss - 3.146279811859131
# Evaluation loss: 4.4641614
# Iteration 12360 / 17190: Training loss - 3.3363747596740723
# Iteration 12370 / 17190: Training loss - 3.3227317333221436
# Iteration 12380 / 17190: Training loss - 3.478803873062134
# Iteration 12390 / 17190: Training loss - 3.0786375999450684
# Iteration 12400 / 17190: Training loss - 3.62298846244812
# Evaluation loss: 5.253586
# Iteration 12410 / 17190: Training loss - 3.6389381885528564
# Iteration 12420 / 17190: Training loss - 3.484095335006714
# Iteration 12430 / 17190: Training loss - 3.0613205432891846
# Iteration 12440 / 17190: Training loss - 2.942687511444092
# Iteration 12450 / 17190: Training loss - 3.462555170059204
# Evaluation loss: 5.0826
# Iteration 12460 / 17190: Training loss - 3.7326834201812744
# Iteration 12470 / 17190: Training loss - 3.5182137489318848
# Iteration 12480 / 17190: Training loss - 3.3466477394104004
# Iteration 12490 / 17190: Training loss - 2.882941484451294
# Iteration 12500 / 17190: Training loss - 3.0453109741210938
# Evaluation loss: 4.8310323
# Iteration 12510 / 17190: Training loss - 2.930002450942993
# Iteration 12520 / 17190: Training loss - 3.114358425140381
# Iteration 12530 / 17190: Training loss - 2.9544472694396973
# Iteration 12540 / 17190: Training loss - 3.147895336151123
# Iteration 12550 / 17190: Training loss - 2.6463992595672607
# Evaluation loss: 4.8286543
# Iteration 12560 / 17190: Training loss - 3.025660514831543
# Iteration 12570 / 17190: Training loss - 3.229918956756592
# Iteration 12580 / 17190: Training loss - 3.4300715923309326
# Iteration 12590 / 17190: Training loss - 3.1794750690460205
# Iteration 12600 / 17190: Training loss - 3.6651978492736816
# Evaluation loss: 3.9772596
# Iteration 12610 / 17190: Training loss - 2.967104434967041
# Iteration 12620 / 17190: Training loss - 3.362531900405884
# Iteration 12630 / 17190: Training loss - 3.1574907302856445
# Iteration 12640 / 17190: Training loss - 3.006784677505493
# Iteration 12650 / 17190: Training loss - 3.304795503616333
# Evaluation loss: 5.2110753
# Iteration 12660 / 17190: Training loss - 3.1386184692382812
# Iteration 12670 / 17190: Training loss - 3.308687210083008
# Iteration 12680 / 17190: Training loss - 2.864898204803467
# Iteration 12690 / 17190: Training loss - 3.4448351860046387
# Iteration 12700 / 17190: Training loss - 3.1943469047546387
# Evaluation loss: 5.5479474
# Iteration 12710 / 17190: Training loss - 2.976811647415161
# Iteration 12720 / 17190: Training loss - 3.130969285964966
# Iteration 12730 / 17190: Training loss - 3.0175867080688477
# Iteration 12740 / 17190: Training loss - 2.9981632232666016
# Iteration 12750 / 17190: Training loss - 2.7760393619537354
# Evaluation loss: 4.9021726
# Iteration 12760 / 17190: Training loss - 2.7421388626098633
# Iteration 12770 / 17190: Training loss - 3.8776867389678955
# Iteration 12780 / 17190: Training loss - 2.825287103652954
# Iteration 12790 / 17190: Training loss - 3.383314847946167
# Iteration 12800 / 17190: Training loss - 3.1420211791992188
# Evaluation loss: 5.4608326
# Iteration 12810 / 17190: Training loss - 3.302626848220825
# Iteration 12820 / 17190: Training loss - 3.3463473320007324
# Iteration 12830 / 17190: Training loss - 2.874830961227417
# Iteration 12840 / 17190: Training loss - 3.113431930541992
# Iteration 12850 / 17190: Training loss - 3.195634126663208
# Evaluation loss: 4.433213
# Iteration 12860 / 17190: Training loss - 3.2103381156921387
# Iteration 12870 / 17190: Training loss - 2.8235561847686768
# Epoch: 7
# Iteration 12880 / 17190: Training loss - 3.2063233852386475
# Iteration 12890 / 17190: Training loss - 3.1066441535949707
# Iteration 12900 / 17190: Training loss - 3.1235620975494385
# Evaluation loss: 5.240531
# Iteration 12910 / 17190: Training loss - 3.6132256984710693
# Iteration 12920 / 17190: Training loss - 3.0861124992370605
# Iteration 12930 / 17190: Training loss - 3.35267972946167
# Iteration 12940 / 17190: Training loss - 3.1716268062591553
# Iteration 12950 / 17190: Training loss - 2.946578025817871
# Evaluation loss: 4.9862256
# Iteration 12960 / 17190: Training loss - 3.2955830097198486
# Iteration 12970 / 17190: Training loss - 2.942838191986084
# Iteration 12980 / 17190: Training loss - 3.1903505325317383
# Iteration 12990 / 17190: Training loss - 3.155794143676758
# Iteration 13000 / 17190: Training loss - 3.141907215118408
# Evaluation loss: 5.1927733
# Iteration 13010 / 17190: Training loss - 3.251971960067749
# Iteration 13020 / 17190: Training loss - 3.1907875537872314
# Iteration 13030 / 17190: Training loss - 2.9926071166992188
# Iteration 13040 / 17190: Training loss - 3.3336400985717773
# Iteration 13050 / 17190: Training loss - 3.5243887901306152
# Evaluation loss: 4.939513
# Iteration 13060 / 17190: Training loss - 3.149360179901123
# Iteration 13070 / 17190: Training loss - 3.617647409439087
# Iteration 13080 / 17190: Training loss - 3.050743341445923
# Iteration 13090 / 17190: Training loss - 2.6746134757995605
# Iteration 13100 / 17190: Training loss - 3.3615562915802
# Evaluation loss: 4.6336384
# Iteration 13110 / 17190: Training loss - 3.382943630218506
# Iteration 13120 / 17190: Training loss - 2.724255323410034
# Iteration 13130 / 17190: Training loss - 3.078490972518921
# Iteration 13140 / 17190: Training loss - 3.4806482791900635
# Iteration 13150 / 17190: Training loss - 3.1712899208068848
# Evaluation loss: 4.637274
# Iteration 13160 / 17190: Training loss - 3.047034740447998
# Iteration 13170 / 17190: Training loss - 2.828378438949585
# Iteration 13180 / 17190: Training loss - 3.1367831230163574
# Iteration 13190 / 17190: Training loss - 3.05088210105896
# Iteration 13200 / 17190: Training loss - 3.359787702560425
# Evaluation loss: 5.4464555
# Iteration 13210 / 17190: Training loss - 3.4209139347076416
# Iteration 13220 / 17190: Training loss - 3.4639828205108643
# Iteration 13230 / 17190: Training loss - 3.0903995037078857
# Iteration 13240 / 17190: Training loss - 3.1495039463043213
# Iteration 13250 / 17190: Training loss - 2.913763999938965
# Evaluation loss: 4.8990626
# Iteration 13260 / 17190: Training loss - 2.834047555923462
# Iteration 13270 / 17190: Training loss - 2.9408462047576904
# Iteration 13280 / 17190: Training loss - 3.1614773273468018
# Iteration 13290 / 17190: Training loss - 3.5026543140411377
# Iteration 13300 / 17190: Training loss - 3.4607961177825928
# Evaluation loss: 4.577215
# Iteration 13310 / 17190: Training loss - 3.1218340396881104
# Iteration 13320 / 17190: Training loss - 3.2218306064605713
# Iteration 13330 / 17190: Training loss - 2.8287994861602783
# Iteration 13340 / 17190: Training loss - 3.4742774963378906
# Iteration 13350 / 17190: Training loss - 2.8304829597473145
# Evaluation loss: 4.790828
# Iteration 13360 / 17190: Training loss - 3.2886571884155273
# Iteration 13370 / 17190: Training loss - 2.7975199222564697
# Iteration 13380 / 17190: Training loss - 2.4410154819488525
# Iteration 13390 / 17190: Training loss - 3.138852119445801
# Iteration 13400 / 17190: Training loss - 3.5189545154571533
# Evaluation loss: 5.177708
# Iteration 13410 / 17190: Training loss - 2.6555068492889404
# Iteration 13420 / 17190: Training loss - 3.2088208198547363
# Iteration 13430 / 17190: Training loss - 3.0477888584136963
# Iteration 13440 / 17190: Training loss - 3.2393603324890137
# Iteration 13450 / 17190: Training loss - 2.766258478164673
# Evaluation loss: 5.317422
# Iteration 13460 / 17190: Training loss - 3.4440324306488037
# Iteration 13470 / 17190: Training loss - 3.524571657180786
# Iteration 13480 / 17190: Training loss - 3.289440631866455
# Iteration 13490 / 17190: Training loss - 2.9461123943328857
# Iteration 13500 / 17190: Training loss - 3.036255121231079
# Evaluation loss: 5.3767853
# Iteration 13510 / 17190: Training loss - 3.192779064178467
# Iteration 13520 / 17190: Training loss - 3.031733512878418
# Iteration 13530 / 17190: Training loss - 2.6599183082580566
# Iteration 13540 / 17190: Training loss - 3.559032917022705
# Iteration 13550 / 17190: Training loss - 3.2721474170684814
# Evaluation loss: 4.946006
# Iteration 13560 / 17190: Training loss - 3.5449609756469727
# Iteration 13570 / 17190: Training loss - 3.431999921798706
# Iteration 13580 / 17190: Training loss - 2.860957145690918
# Iteration 13590 / 17190: Training loss - 3.585507392883301
# Iteration 13600 / 17190: Training loss - 3.6213173866271973
# Evaluation loss: 5.0779214
# Iteration 13610 / 17190: Training loss - 3.1144027709960938
# Iteration 13620 / 17190: Training loss - 3.3379859924316406
# Iteration 13630 / 17190: Training loss - 2.5494916439056396
# Iteration 13640 / 17190: Training loss - 3.2025387287139893
# Iteration 13650 / 17190: Training loss - 3.2454679012298584
# Evaluation loss: 4.921856
# Iteration 13660 / 17190: Training loss - 3.267890214920044
# Iteration 13670 / 17190: Training loss - 3.1949546337127686
# Iteration 13680 / 17190: Training loss - 3.0533955097198486
# Iteration 13690 / 17190: Training loss - 3.293457269668579
# Iteration 13700 / 17190: Training loss - 3.234316110610962
# Evaluation loss: 5.3248916
# Iteration 13710 / 17190: Training loss - 3.0595831871032715
# Iteration 13720 / 17190: Training loss - 3.4814131259918213
# Iteration 13730 / 17190: Training loss - 3.1693778038024902
# Iteration 13740 / 17190: Training loss - 3.2849817276000977
# Iteration 13750 / 17190: Training loss - 3.1259334087371826
# Evaluation loss: 5.276921
# Iteration 13760 / 17190: Training loss - 3.234797954559326
# Iteration 13770 / 17190: Training loss - 3.4599807262420654
# Iteration 13780 / 17190: Training loss - 3.7212588787078857
# Iteration 13790 / 17190: Training loss - 3.1855313777923584
# Iteration 13800 / 17190: Training loss - 3.3788881301879883
# Evaluation loss: 4.9946437
# Iteration 13810 / 17190: Training loss - 3.0947041511535645
# Iteration 13820 / 17190: Training loss - 3.1817362308502197
# Iteration 13830 / 17190: Training loss - 3.6743032932281494
# Iteration 13840 / 17190: Training loss - 2.958515167236328
# Iteration 13850 / 17190: Training loss - 2.550844669342041
# Evaluation loss: 5.1614003
# Iteration 13860 / 17190: Training loss - 3.2571985721588135
# Iteration 13870 / 17190: Training loss - 3.1474459171295166
# Iteration 13880 / 17190: Training loss - 2.9810025691986084
# Iteration 13890 / 17190: Training loss - 2.9277470111846924
# Iteration 13900 / 17190: Training loss - 2.8948864936828613
# Evaluation loss: 4.7886677
# Iteration 13910 / 17190: Training loss - 2.995495080947876
# Iteration 13920 / 17190: Training loss - 3.1347081661224365
# Iteration 13930 / 17190: Training loss - 3.1625587940216064
# Iteration 13940 / 17190: Training loss - 3.4393701553344727
# Iteration 13950 / 17190: Training loss - 3.0119175910949707
# Evaluation loss: 4.7959957
# Epoch: 8
# Iteration 13960 / 17190: Training loss - 3.2176856994628906
# Iteration 13970 / 17190: Training loss - 2.7169721126556396
# Iteration 13980 / 17190: Training loss - 3.3928637504577637
# Iteration 13990 / 17190: Training loss - 2.481825828552246
# Iteration 14000 / 17190: Training loss - 2.990717887878418
# Evaluation loss: 4.6525064
# Iteration 14010 / 17190: Training loss - 2.7343268394470215
# Iteration 14020 / 17190: Training loss - 2.5298492908477783
# Iteration 14030 / 17190: Training loss - 3.445308208465576
# Iteration 14040 / 17190: Training loss - 2.865316152572632
# Iteration 14050 / 17190: Training loss - 3.1567225456237793
# Evaluation loss: 4.9618726
# Iteration 14060 / 17190: Training loss - 2.7808237075805664
# Iteration 14070 / 17190: Training loss - 3.3335862159729004
# Iteration 14080 / 17190: Training loss - 2.8465051651000977
# Iteration 14090 / 17190: Training loss - 3.3151769638061523
# Iteration 14100 / 17190: Training loss - 2.4774856567382812
# Evaluation loss: 5.5254188
# Iteration 14110 / 17190: Training loss - 2.893385410308838
# Iteration 14120 / 17190: Training loss - 3.4455690383911133
# Iteration 14130 / 17190: Training loss - 3.107050895690918
# Iteration 14140 / 17190: Training loss - 2.982041120529175
# Iteration 14150 / 17190: Training loss - 2.846053123474121
# Evaluation loss: 4.76975
# Iteration 14160 / 17190: Training loss - 3.050752639770508
# Iteration 14170 / 17190: Training loss - 3.3183608055114746
# Iteration 14180 / 17190: Training loss - 2.826545238494873
# Iteration 14190 / 17190: Training loss - 2.9487853050231934
# Iteration 14200 / 17190: Training loss - 3.196911096572876
# Evaluation loss: 5.418695
# Iteration 14210 / 17190: Training loss - 2.708061933517456
# Iteration 14220 / 17190: Training loss - 2.911885976791382
# Iteration 14230 / 17190: Training loss - 2.694413185119629
# Iteration 14240 / 17190: Training loss - 2.7999227046966553
# Iteration 14250 / 17190: Training loss - 2.8122379779815674
# Evaluation loss: 4.4741883
# Iteration 14260 / 17190: Training loss - 2.733335256576538
# Iteration 14270 / 17190: Training loss - 2.917811393737793
# Iteration 14280 / 17190: Training loss - 2.9113824367523193
# Iteration 14290 / 17190: Training loss - 3.2076663970947266
# Iteration 14300 / 17190: Training loss - 3.2103710174560547
# Evaluation loss: 4.7101393
# Iteration 14310 / 17190: Training loss - 3.2074832916259766
# Iteration 14320 / 17190: Training loss - 3.4180729389190674
# Iteration 14330 / 17190: Training loss - 3.3100507259368896
# Iteration 14340 / 17190: Training loss - 3.372568368911743
# Iteration 14350 / 17190: Training loss - 2.9305760860443115
# Evaluation loss: 4.9183164
# Iteration 14360 / 17190: Training loss - 2.8688085079193115
# Iteration 14370 / 17190: Training loss - 3.300875663757324
# Iteration 14380 / 17190: Training loss - 3.5101397037506104
# Iteration 14390 / 17190: Training loss - 2.637972354888916
# Iteration 14400 / 17190: Training loss - 2.9956793785095215
# Evaluation loss: 4.194946
# Iteration 14410 / 17190: Training loss - 3.267948865890503
# Iteration 14420 / 17190: Training loss - 2.959364175796509
# Iteration 14430 / 17190: Training loss - 2.995790481567383
# Iteration 14440 / 17190: Training loss - 2.7369511127471924
# Iteration 14450 / 17190: Training loss - 2.6704623699188232
# Evaluation loss: 5.172038
# Iteration 14460 / 17190: Training loss - 3.177445888519287
# Iteration 14470 / 17190: Training loss - 3.2460222244262695
# Iteration 14480 / 17190: Training loss - 2.9357545375823975
# Iteration 14490 / 17190: Training loss - 3.3721628189086914
# Iteration 14500 / 17190: Training loss - 3.233597993850708
# Evaluation loss: 5.3331237
# Iteration 14510 / 17190: Training loss - 2.9847543239593506
# Iteration 14520 / 17190: Training loss - 2.8408868312835693
# Iteration 14530 / 17190: Training loss - 2.574277877807617
# Iteration 14540 / 17190: Training loss - 3.038609027862549
# Iteration 14550 / 17190: Training loss - 2.460026502609253
# Evaluation loss: 5.093696
# Iteration 14560 / 17190: Training loss - 3.060696840286255
# Iteration 14570 / 17190: Training loss - 2.399547576904297
# Iteration 14580 / 17190: Training loss - 3.1331489086151123
# Iteration 14590 / 17190: Training loss - 3.2869129180908203
# Iteration 14600 / 17190: Training loss - 2.7903835773468018
# Evaluation loss: 4.2861333
# Iteration 14610 / 17190: Training loss - 3.1391546726226807
# Iteration 14620 / 17190: Training loss - 3.431492805480957
# Iteration 14630 / 17190: Training loss - 3.076336622238159
# Iteration 14640 / 17190: Training loss - 2.7756385803222656
# Iteration 14650 / 17190: Training loss - 2.72066330909729
# Evaluation loss: 5.260266
# Iteration 14660 / 17190: Training loss - 3.129702091217041
# Iteration 14670 / 17190: Training loss - 3.206108808517456
# Iteration 14680 / 17190: Training loss - 3.1679720878601074
# Iteration 14690 / 17190: Training loss - 2.9572336673736572
# Iteration 14700 / 17190: Training loss - 3.129991292953491
# Evaluation loss: 4.8857794
# Iteration 14710 / 17190: Training loss - 2.9267098903656006
# Iteration 14720 / 17190: Training loss - 3.159396171569824
# Iteration 14730 / 17190: Training loss - 3.07210111618042
# Iteration 14740 / 17190: Training loss - 3.1153454780578613
# Iteration 14750 / 17190: Training loss - 2.829192876815796
# Evaluation loss: 5.073278
# Iteration 14760 / 17190: Training loss - 3.4754652976989746
# Iteration 14770 / 17190: Training loss - 2.7886574268341064
# Iteration 14780 / 17190: Training loss - 3.2764313220977783
# Iteration 14790 / 17190: Training loss - 3.0912530422210693
# Iteration 14800 / 17190: Training loss - 2.6920883655548096
# Evaluation loss: 5.5594525
# Iteration 14810 / 17190: Training loss - 2.876275062561035
# Iteration 14820 / 17190: Training loss - 3.0956432819366455
# Iteration 14830 / 17190: Training loss - 2.848344087600708
# Iteration 14840 / 17190: Training loss - 3.2882161140441895
# Iteration 14850 / 17190: Training loss - 3.1947152614593506
# Evaluation loss: 4.9250684
# Iteration 14860 / 17190: Training loss - 2.571428060531616
# Iteration 14870 / 17190: Training loss - 2.9954845905303955
# Iteration 14880 / 17190: Training loss - 2.882678747177124
# Iteration 14890 / 17190: Training loss - 2.8300318717956543
# Iteration 14900 / 17190: Training loss - 3.238553524017334
# Evaluation loss: 5.217073
# Iteration 14910 / 17190: Training loss - 2.9172914028167725
# Iteration 14920 / 17190: Training loss - 2.996278762817383
# Iteration 14930 / 17190: Training loss - 2.945496082305908
# Iteration 14940 / 17190: Training loss - 3.3502085208892822
# Iteration 14950 / 17190: Training loss - 3.1359331607818604
# Evaluation loss: 4.877749
# Iteration 14960 / 17190: Training loss - 3.0594475269317627
# Iteration 14970 / 17190: Training loss - 2.8634676933288574
# Iteration 14980 / 17190: Training loss - 3.198894500732422
# Iteration 14990 / 17190: Training loss - 2.7081410884857178
# Iteration 15000 / 17190: Training loss - 3.363570213317871
# Evaluation loss: 4.9334397
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-d2bdeb126bea> in <module>()
#      27                               model.encoder_mask: batch_input_mask, model.decoder_mask: batch_output_mask}
#      28
# ---> 29             train_loss, _, step = sess.run([model.loss, model.train_op, model.global_step], feed_dict=feed)
#      30
#      31             if iteration % print_per_iter == 0:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
plt.plot(iterations, train_losses)
plt.plot(iterations, val_losses)
plt.show()

# %%
plt.plot(iterations, train_losses)
plt.plot(iterations, val_losses)
plt.show()

# %% [markdown]
# # Predict

# %%
model_file = root_folder + "models/transformer_model2"
with tf.Session() as sess:
    model.saver.restore(sess, model_file)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Project-Lion/models/transformer_model2

# %%
def make_prediction(model, model_file, questions=[], size=10, start_idx=None, text_file=None):
  
  sample = questions == []
  if sample:
    if start_idx == None:
      start_idx = np.random.randint(training_size, len(qa) - size)
    questions = [q for q, a in qa[start_idx:start_idx + size]]
    answers = [a for q, a in qa[start_idx:start_idx + size]]

  with tf.Session() as sess:

    model.saver.restore(sess, model_file)
    
    if sample:
      print("\nJokes starting from index:", start_idx)

    for i in range(len(questions)):
      question = questions[i]

      # Process the capitalization with the preprocess_capitalization of the capita package.
      question = capita.preprocess_capitalization(question)

      # Numerize the tokens of the processed text using the loaded sentencepiece model.
      numerized = sp.EncodeAsIds(question)
      # Pad the sequence and keep the mask of the input
      padded, mask = pad_sequence(numerized, pad_index, input_len)

      # Making the news article into a batch of size one, to be fed to the neural network.
      encoder_input = np.array([padded])
      encoder_mask = np.array([mask])

      decoded_so_far = [0]

      for j in range(output_len):
        padded_decoder_input, decoder_mask = pad_sequence(decoded_so_far, pad_index, output_len)
        padded_decoder_input = [padded_decoder_input]
        decoder_mask = [decoder_mask]
        #print("========================")
        #print(padded_decoder_input)
        # Use the model to find the distrbution over the vocabulary for the next word
        logits = sess.run(model.decoded_logits, feed_dict={model.source_sequence: encoder_input, model.encoder_mask: encoder_mask, model.target_sequence: padded_decoder_input, model.decoder_mask: decoder_mask})

        chosen_words = np.argmax(logits, axis=2) # Take the argmax, getting the most likely next word
        decoded_so_far.append(int(chosen_words[0, j])) # We add it to the summary so far
      print(question, file = text_file)
      if sample:
        answer = answers[i]
        #print("Answer:", answer)
      decoded_words = [vocab[i] for i in decoded_so_far]
      print("".join(decoded_words[1:]).replace("▁", " ")[1:], file = text_file)
      print("", file = text_file)

# %%
with open(root_folder + "transformer_output_jokes.txt", "w") as text_file:
  make_prediction(model, model_file, size = 500, start_idx = 0, text_file = text_file)
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Project-Lion/models/transformer_model2
#
# Jokes starting from index: 0

# %%
predict(model, model_file)
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Project-Lion/models/transformer_model2
#
# Jokes starting from index: 55899
#
# =================================================
#
# Question: why is the liberty bell like a dropped easter egg
# Answer: because theyre both cracked
# Predicted answer: <unk>  becausebecause its they allre have dick as year```
#
# =================================================
#
# Question: how do you find a blind man in a strip club
# Answer: it isnt hard
# Predicted answer: <unk> you you say tell its you there so` cool```s``
#
# =================================================
#
# Question: hows it hanging
# Answer: directly below the point of suspension
# Predicted answer: <unk> they itsre not my likely year`````````
#
# =================================================
#
# Question: heard about the magic tractor
# Answer: it went down a road and turned into a field
# Predicted answer: <unk> it it was went actually looking time for` a yeah red ded n`
#
# =================================================
#
# Question: why are republicans so insistent on a war in the middle east
# Answer: because its good christian values to invade the middle east
# Predicted answer: <unk>  becausebecause they they arere in  there cross` fors`
#
# =================================================
#
# Question: how do you get a nun pregnant
# Answer: dress her up like an altar boy
# Predicted answer: <unk> dress dress her behind up her as as it itgu by would cross self`
#
# =================================================
#
# Question: how do you make holy water
# Answer: you boil the hell out of it credit to tasteless
# Predicted answer: <unk> you you just just boil put the it hell once of` it```
#
# =================================================
#
# Question: how is a chronic disease unlike the th doctor but like the th doctor
# Answer: it sticks around for more than  season and doesnt want to go
# Predicted answer: <unk> they theyrere both so a very man large``````
#
# =================================================
#
# Question: a duckling joke why do baby ducks walk softly
# Answer: because they cant walk hardly
# Predicted answer: <unk>  becausebecause they they arere made similar a igno  who`
#
# =================================================
#
# Question: a years old male tourist swept away in amazon river where did he end up
# Answer: local brazilian newspaper
# Predicted answer: <unk>  iim think a  chim just so f auck man`

# %%
predict(model, model_file, questions=["why did the chicken cross the street"])
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Project-Lion/models/transformer_model2
#
# =================================================
#
# Question: why did the chicken cross the street
# Predicted answer: <unk>  becausebecause it it was was a a chicken chicken flew```
